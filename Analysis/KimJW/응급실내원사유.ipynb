# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("/Users/stone/Desktop/필요/4_2/BigData/팀플/응급실+내원사유+현황_20231003161942.xlsx")

# %%
df.head(20)
# Out:
#     연령별(1)    연령별(2)  성별(1)     2021  2021.1     2021.2     2021.3     2021.4  \
# 0   연령별(1)    연령별(2)  성별(1)        계       계          계          계          계
# 1   연령별(1)    연령별(2)  성별(1)       소계      질병  질병외: 손상기전  질병외: 손상기전  질병외: 손상기전
# 2   연령별(1)    연령별(2)  성별(1)       소계      소계         소계       교통사고         추락
# 3       합계        소계      계  1157022  838285     269238      32679      20799
# 4      NaN       NaN     남자   558077  397270     140441      21177      11440
# 5      NaN       NaN     여자   598945  441015     128797      11502       9359
# 6      NaN      1세미만      계    15083   10646       4211         60       2028
# 7      NaN    1 - 9세      계    87744   46143      39304       1605       5161
# 8      NaN  10 - 19세      계    60479   38805      19235       2958        931
# 9      NaN  20 - 29세      계   159900  105357      45111       6661       1552
# 10     NaN  30 - 39세      계   143318   98970      33763       5422       1234
# ...

# %%
df1 = df.transpose()	#행 열 전환

# %%
df1.head(10)
# Out:
#             0          1       2        3       4       5      6       7   \
# 연령별(1)  연령별(1)     연령별(1)  연령별(1)       합계     NaN     NaN    NaN     NaN
# 연령별(2)  연령별(2)     연령별(2)  연령별(2)       소계     NaN     NaN   1세미만  1 - 9세
# 성별(1)    성별(1)      성별(1)   성별(1)        계      남자      여자      계       계
# 2021         계         소계      소계  1157022  558077  598945  15083   87744
# 2021.1       계         질병      소계   838285  397270  441015  10646   46143
# 2021.2       계  질병외: 손상기전      소계   269238  140441  128797   4211   39304
# 2021.3       계  질병외: 손상기전    교통사고    32679   21177   11502     60    1605
# 2021.4       계  질병외: 손상기전      추락    20799   11440    9359   2028    5161
# 2021.5       계  질병외: 손상기전    미끄러짐    56086   26646   29440    256    7778
# 2021.6       계  질병외: 손상기전     부딪힘    47772   28702   19070    713   12477
#
#               8         9         10        11        12        13        14  \
# ...
