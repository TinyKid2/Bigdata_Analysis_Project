# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# !sudo fc-cache -fv
import matplotlib.pyplot as plt # 맷플롯립 import 하기
plt.rcParams['font.family'] = 'NanumBarunGothic' # 나눔바른고딕 적용하기
# Out:
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 2 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
import pandas as pd
import numpy as np
import seaborn as sns
# import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# import matplotlib.pyplot as plt # 맷플롯립 import 하기
# plt.rcParams['font.family'] = 'NanumBarunGothic' # 나눔바른고딕 적용하기

# %%
# !pip install openpyxl

# %%
import os
import google.colab
google.colab.drive.mount('/content/drive/')
# google.colab.drive.mount('/content/drive/MyDrive/Bigdata/N_data')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# # 우선 데이터 다 불러오기.

# %%
data_path = "/content/drive/MyDrive/Bigdata/데이터_모음"

# %%
import os

# %%
data_size = os.path.getsize(data_path)

# %%
print(data_size)
# Out:
# 4096

# %%
for i in os.listdir(data_path):
  print(i)
# Out:
# 행정구역_시군구_별__성별_인구수_20231115231756.xlsx의 사본
# 응급의학전문의+및+응급의학전공의+현황+-+시도별,+연도별 (1).csv의 사본
# 응급의료기관+및+응급의료시설+현황+-+시도별,+연도별.csv의 사본
# 응급의료기관+응급실+전담+의료진+현황+-+기관유형별,+시도별,+연도별.csv의 사본
# 응급의료기관+병상+현황+-+시도별,+연도별.csv의 사본
# 응급의료기관+응급실+전담+의료진+현황+-+기관유형별,+시도별,+연도별 (1).csv의 사본
# 전체+구급차+및+배치된+의료인력+현황+-+시도별,+연도별 (1).csv의 사본
# 인구+백만+명당+응급의료기관+현황+-+시도별,+연도별.csv의 사본
# 응급의료기관+병상+현황+-+시도별,+연도별 (1).csv의 사본
# 응급의학전문의+및+응급의학전공의+현황+-+시도별,+연도별.csv의 사본
# 응급의료기관+및+응급의료시설+현황+-+시도별,+연도별 (1).csv의 사본
# 응급실+내원사유+현황_20231012013440.xlsx의 사본
# ...

# %%
data_list = os.listdir(data_path)
print(len(data_list))
# Out:
# 105

# %%
df_1 = pd.read_excel(data_path + "/" + data_list[0])
df_2 = pd.read_excel(data_path + "/" +data_list[1])
df_3 = pd.read_excel(data_path + "/" +data_list[2])
df_4 = pd.read_excel(data_path + "/" +data_list[3])
df_5 = pd.read_excel(data_path + "/" +data_list[4])
df_6 = pd.read_excel(data_path + "/" +data_list[5])
df_7 = pd.read_excel(data_path + "/" +data_list[6])
df_8 = pd.read_excel(data_path + "/" +data_list[7])
df_9 = pd.read_excel(data_path + "/" +data_list[8])
df_10 = pd.read_excel(data_path + "/" +data_list[9])
df_11 = pd.read_excel(data_path + "/" +data_list[10])
df_12 = pd.read_excel(data_path + "/" +data_list[11])
df_13 = pd.read_excel(data_path + "/" +data_list[12])
df_14 = pd.read_excel(data_path + "/" +data_list[13])
df_15 = pd.read_excel(data_path + "/" +data_list[14])
df_16 = pd.read_excel(data_path + "/" +data_list[15])
df_17 = pd.read_excel(data_path + "/" +data_list[16])
df_18 = pd.read_excel(data_path + "/" +data_list[17])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-fa689abcf719> in <cell line: 1>()
# ----> 1 df_1 = pd.read_excel(data_path + "/" + data_list[0])
#       2 df_2 = pd.read_excel(data_path + "/" +data_list[1])
#       3 df_3 = pd.read_excel(data_path + "/" +data_list[2])
#       4 df_4 = pd.read_excel(data_path + "/" +data_list[3])
#       5 df_5 = pd.read_excel(data_path + "/" +data_list[4])
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
# ...

# %% [markdown]
# ### 데이터 목록
#
# |이름|df_변수명|
# |---|---|
# |응급의료기관+및+응급의료시설+현황+-+시도별,+연도별.csv|df_1|
# |응급의료기관+병상+현황+-+시도별,+연도별.csv|df_2|
# |응급의학전문의+및+응급의학전공의+현황+-+시도별,+연도별.csv|df_3|
# |1급+응급구조사+및+2급+응급구조사+합격자+현황+-+시도별,+연도별.csv|df_4|
# |응급의료기관+응급실+전담+의료진+현황+-+기관유형별,+시도별,+연도별.csv|df_5|
# |전체+구급차+및+배치된+의료인력+현황+-+시도별,+연도별.csv|df_6|
# |인구+백만+명당+응급의료기관+현황+-+시도별,+연도별.csv|df_7|
# |행정구역_시군구_별__성별_인구수_20231208132957.xls|df_8|
# |응급진료결과(시도별).csv|df_9|
# |입원+후+결과(시도별).csv|df_10|
# |최초+중증도+분류(KTAS)+결과(시도별).csv|df_11|
# |응급실+재실시간(시도별).csv|df_12|
# |질병여부+및+손상기전+용급실+이용(시도별).csv|df_13|
# |응급의료기관+자원별+이용자+현황(기관유형별,+시도별).csv|df_14|
# |응급진료결과(성별,+연령별).csv|df_15|
# |응급의료기관+자원별+이용자+현황(기관유형별,+시도별) (3).csv|df_16|
# |응급의료기관+자원별+이용자+현황(기관유형별,+시도별) (2).csv|df_17|
# |행정구역_시군구_별__성별_인구수_2022년12월.xlsx|df_18|

# %%
df = pd.DataFrame()

# %% [markdown]
# ### Q1. 지역별로 중증도가 차이가 나는가? 2022년 기준
# ### Q2. 중증도를 보았을때, 병상갯수가 차이가 나는가?
# ### Q3. 나이별로 중증도가 얼마나 차이가 나는가?

# %% [markdown]
# ## Q1. 지역별로 중증도가 차이가 나는가? 2022년 기준
# ### 퍼센티지는 별로 차이나지 않음.

# %%
df_11.head(80)
# Out:
#                                                    No    분류      분류.1  \
# 0                                                  No    분류        분류
# 1                                                  No    분류        분류
# 2                                                  No    분류        분류
# 3                                                   1    전체        전체
# 4                                                   2  기관유형  권역응급의료센터
# 5                                                   3  기관유형  지역응급의료센터
# 6                                                   4  기관유형  지역응급의료기관
# 7                                                   5    서울        서울
# 8                                                   6    부산        부산
# 9                                                   7    대구        대구
# 10                                                  8    인천        인천
# 11                                                  9    광주        광주
# ...

# %%
df_11.reset_index()
# Out:
#     index                                                 No    분류      분류.1  \
# 0       0                                                 No    분류        분류
# 1       1                                                 No    분류        분류
# 2       2                                                 No    분류        분류
# 3       3                                                  1    전체        전체
# 4       4                                                  2  기관유형  권역응급의료센터
# 5       5                                                  3  기관유형  지역응급의료센터
# 6       6                                                  4  기관유형  지역응급의료기관
# 7       7                                                  5    서울        서울
# 8       8                                                  6    부산        부산
# 9       9                                                  7    대구        대구
# 10     10                                                  8    인천        인천
# ...

# %%
cities = []
for i in df_11['분류.1']:
  if i not in cities:
    cities.append(i)
print(cities)
# Out:
# ['분류', '전체', '권역응급의료센터', '지역응급의료센터', '지역응급의료기관', '서울', '부산', '대구', '인천', '광주', '대전', '울산', '세종', '경기', '강원', '충북', '충남', '전북', '전남', '경북', '경남', '제주', 0]

# %%
# cities.remove('전체')
# cities.remove('미상')

# cities.remove(cities[-1]) # 한번만 실행하기, nan값 없애는 용도
# cities.remove(cities[1])
cities = ['서울', '부산', '대구', '인천', '광주', '대전', '울산', '세종', '경기', '강원', '충북', '충남', '전북', '전남', '경북', '경남', '제주']
print(cities)
# Out:
# ['서울', '부산', '대구', '인천', '광주', '대전', '울산', '세종', '경기', '강원', '충북', '충남', '전북', '전남', '경북', '경남', '제주']

# %%
cities
# Out:
# ['분류',
#  '권역응급의료센터',
#  '지역응급의료센터',
#  '지역응급의료기관',
#  '서울',
#  '부산',
#  '대구',
#  '인천',
#  '광주',
#  '대전',
#  '울산',
#  '세종',
#  '경기',
#  '강원',
#  '충북',
#  '충남',
#  '전북',
#  '전남',
#  '경북',
#  '경남',
#  '제주',
#  nan]

# %%
df_11 = df_11.fillna(0)
df_11['2022년'][3:] = df_11['2022년'][3:].str.replace(',', '').astype(float)

# %%
df = pd.DataFrame()
for i in (cities):
  df['분류'] = cities

row = []
# df.head(30)
for city in cities:
    # 해당 도시에 해당하는 행 중에서 '2022년' 값이 NaN이 아닌 행만 선택
    selected_rows = df_11[(df_11['분류.1'] == f'{city}') & ~df_11['2022년'].isna()]
    selected_rows1 = selected_rows['2022년'].tolist()
    row.append(selected_rows1)
    # print(selected_rows1)
    # df[f'{city}_2022년_중증인원수'] = selected_rows
    # print(type(selected_rows['2022년']))

# %%
# print(row)
print(row[0])
# Out:
# ['이용자 수', '건', '원자료']

# %%
row[0] = 0

# %%
print(len(row))
# Out:
# 22

# %%
df['이용자수'] = row

# %%
df.head(30)
# Out:
#           분류         이용자수
# 0         분류            0
# 1   권역응급의료센터  [1526727.0]
# 2   지역응급의료센터  [3286330.0]
# 3   지역응급의료기관  [2427812.0]
# 4         서울  [1224258.0]
# 5         부산   [417272.0]
# 6         대구   [352791.0]
# 7         인천   [438030.0]
# 8         광주   [326346.0]
# 9         대전   [201203.0]
# 10        울산   [153870.0]
# 11        세종    [39672.0]
# 12        경기  [1471414.0]
# 13        강원   [306083.0]
# 14        충북   [231866.0]
# 15        충남   [321707.0]
# 16        전북   [304809.0]
# 17        전남   [396994.0]
# 18        경북   [395332.0]
# 19        경남   [513183.0]
# 20        제주   [146039.0]
# 21       NaN           []

# %%
df.head(30)
df = df.reset_index(drop=True)
df.head()
#  df.to_csv("/content/drive/MyDrive/Bigdata/N_data/지역별_최초중증도 분류")

df = pd.read_csv("/content/drive/MyDrive/Bigdata/N_data/지역별_최초중증도 분류")
df.head()
# Out:
#    Unnamed: 0   분류 서울_2022년_중증인원수 부산_2022년_중증인원수 대구_2022년_중증인원수  \
# 0           8   전체        990,391        211,432        174,313
# 1           9  레벨1         11,778          3,544          2,665
# 2          10  레벨2         58,608         16,151         14,666
# 3          11  레벨3        405,812         88,374         99,820
# 4          12  레벨4        387,024         79,401         52,970
#
#   인천_2022년_중증인원수 광주_2022년_중증인원수 대전_2022년_중증인원수 울산_2022년_중증인원수 세종_2022년_중증인원수  \
# 0        361,493        122,758        128,558         69,801         34,530
# 1          5,313            953          1,946            679            329
# 2         18,595          5,957          7,698          4,240          1,440
# 3        153,342         52,825         49,894         27,354         19,666
# 4        141,123         50,616         54,186         30,964         11,073
#
#   경기_2022년_중증인원수 강원_2022년_중증인원수 충북_2022년_중증인원수 충남_2022년_중증인원수 전북_2022년_중증인원수  \
# ...

# %%
df_18.head(30)
# 놀랍게도 응급실 데이터의 도시와 일치한다.
# # 대박
# Out:
#     행정구역(시군구)별   2022.12  2022.12.1  2022.12.2   2023.10  2023.10.1  2023.10.2
# 0   행정구역(시군구)별  총인구수 (명)  남자인구수 (명)  여자인구수 (명)  총인구수 (명)  남자인구수 (명)  여자인구수 (명)
# 1           전국  51439038   25636951   25802087  51354226   25582773   25771453
# 2        서울특별시   9428372    4570048    4858324   9400249    4548150    4852099
# 3        부산광역시   3317812    1619915    1697897   3298213    1608156    1690057
# 4        대구광역시   2363691    1162865    1200826   2376978    1168087    1208891
# 5        인천광역시   2967314    1485175    1482139   2990276    1495744    1494532
# 6        광주광역시   1431050     707299     723751   1421760     702121     719639
# 7        대전광역시   1446072     721245     724827   1443965     720207     723758
# 8        울산광역시   1110663     570368     540295   1104031     567309     536722
# 9      세종특별자치시    383591     191389     192202    386079     192299     193780
# 10         경기도  13589432    6839276    6750156  13627840    6855616    6772224
# ...

# %%
# df['총인구수'] = df_18['2022.12'][1:]
# df = df.drop('총인구수', axis=1)
df_18_1 = df_18.loc[1:,"2022.12"]

# %%
df_18_1.reset_index(drop = True)
# Out:
# 0     51439038
# 1      9428372
# 2      3317812
# 3      2363691
# 4      2967314
# 5      1431050
# 6      1446072
# 7      1110663
# 8       383591
# 9     13589432
# 10     1536498
# 11     1595058
# 12     2123037
# 13     1769607
# 14     1817697
# 15     2600492
# 16     3280493
# 17      678159
# Name: 2022.12, dtype: object

# %%
df.head(30)
# Out:
#    Unnamed: 0   분류 서울_2022년_중증인원수 부산_2022년_중증인원수 대구_2022년_중증인원수  \
# 0           8   전체        990,391        211,432        174,313
# 1           9  레벨1         11,778          3,544          2,665
# 2          10  레벨2         58,608         16,151         14,666
# 3          11  레벨3        405,812         88,374         99,820
# 4          12  레벨4        387,024         79,401         52,970
# 5          13  레벨5        127,018         23,916          4,179
# 6          14   기타            144             45             13
# 7          15   미상              7              1              0
#
#   인천_2022년_중증인원수 광주_2022년_중증인원수 대전_2022년_중증인원수 울산_2022년_중증인원수 세종_2022년_중증인원수  \
# 0        361,493        122,758        128,558         69,801         34,530
# 1          5,313            953          1,946            679            329
# 2         18,595          5,957          7,698          4,240          1,440
# 3        153,342         52,825         49,894         27,354         19,666
# ...

# %%
df['서울_2022년_중증인원수'] = df['서울_2022년_중증인원수'].astype(str).str.replace(',', '')
df['서울_2022년_중증인원수'] = df['서울_2022년_중증인원수'].astype(float)

# %%
df_0 = pd.DataFrame()
# df.columns = df.columns.str.replace(' ', '_')

# %%
cities.remove("분류")

# %%
df_0 = pd.read_csv("/content/drive/MyDrive/Bigdata/N_data/중증환자지역별percentage")
df_0.head(30)
# Out:
#         Unnamed: 0          0             1             2              3  \
# 0       Unnamed: 0        0.0      1.000000      2.000000       3.000000
# 1   서울_2022년_중증인원수   990391.0  11778.000000  58608.000000  405812.000000
# 2    서울_percentage        1.0      0.011892      0.059177       0.409749
# 3   부산_2022년_중증인원수   211432.0   3544.000000  16151.000000   88374.000000
# 4    부산_percentage        1.0      0.016762      0.076389       0.417978
# 5   대구_2022년_중증인원수   174313.0   2665.000000  14666.000000   99820.000000
# 6    대구_percentage        1.0      0.015289      0.084136       0.572648
# 7   인천_2022년_중증인원수   361493.0   5313.000000  18595.000000  153342.000000
# 8    인천_percentage        1.0      0.014697      0.051439       0.424191
# 9   광주_2022년_중증인원수   122758.0    953.000000   5957.000000   52825.000000
# 10   광주_percentage        1.0      0.007763      0.048526       0.430318
# 11  대전_2022년_중증인원수   128558.0   1946.000000   7698.000000   49894.000000
# ...

# %%
for i in cities:
    print(i)
    df_0[f'{i}_2022년_중증인원수'] = df[f'{i}_2022년_중증인원수'].astype(str).str.replace(',', '').astype(float)
    df_0[f'{i}_percentage'] = df[f'{i}_2022년_중증인원수'] / df[f'{i}_2022년_중증인원수'].iloc[0]
# Out:
# 권역응급의료센터
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '권역응급의료센터_2022년_중증인원수'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df_0.head(30)
# Out:
#         Unnamed: 0          0             1             2              3  \
# 0       Unnamed: 0        0.0      1.000000      2.000000       3.000000
# 1   서울_2022년_중증인원수   990391.0  11778.000000  58608.000000  405812.000000
# 2    서울_percentage        1.0      0.011892      0.059177       0.409749
# 3   부산_2022년_중증인원수   211432.0   3544.000000  16151.000000   88374.000000
# 4    부산_percentage        1.0      0.016762      0.076389       0.417978
# 5   대구_2022년_중증인원수   174313.0   2665.000000  14666.000000   99820.000000
# 6    대구_percentage        1.0      0.015289      0.084136       0.572648
# 7   인천_2022년_중증인원수   361493.0   5313.000000  18595.000000  153342.000000
# 8    인천_percentage        1.0      0.014697      0.051439       0.424191
# 9   광주_2022년_중증인원수   122758.0    953.000000   5957.000000   52825.000000
# 10   광주_percentage        1.0      0.007763      0.048526       0.430318
# 11  대전_2022년_중증인원수   128558.0   1946.000000   7698.000000   49894.000000
# ...

# %%
# 데이터 저장
# df_0.to_csv("/content/drive/MyDrive/Bigdata/N_data/중증환자지역별percentage")

# %%
import matplotlib.font_manager as fm
# font_path = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'

# 나눔바른고딕 폰트 등록
# fontprop = fm.FontProperties(fname=font_path, size=12)

# 그래프에서 한글 폰트 설정
# plt.rcParams['font.family'] = 'NanumBarunGothic'
# plt.rcParams['font.size'] = 12

# Seaborn 폰트 설정
# sns.set(font=fontprop.get_name())

# 나눔바른고딕 폰트 적용
# plt.rc('font', family='NanumBarunGothic')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-33-7f878e014232> in <cell line: 12>()
#      10
#      11 # Seaborn 폰트 설정
# ---> 12 sns.set(font=fontprop.get_name())
#      13
#      14 # 나눔바른고딕 폰트 적용
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/font_manager.py in get_name(self)
#     660         Return the name of the font that best matches the font properties.
#     661         """
# --> 662         return get_font(findfont(self)).family_name
#     663
#     664     def get_style(self):
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     295                 f"for the old name will be dropped %(removal)s.")
#     296             kwargs[new] = kwargs.pop(old)
# --> 297         return func(*args, **kwargs)
#     298
#     299     # wrapper() must keep the same documented signature as func(): if we
# ...

# %%
print(cities)
city_mapping = {
    '서울': 'Seoul',
    '부산': 'Busan',
    '대구': 'Daegu',
    '인천': 'Incheon',
    '광주': 'Gwangju',
    '대전': 'Daejeon',
    '울산': 'Ulsan',
    '세종': 'Sejong',
    '경기': 'Gyeonggi',
    '강원': 'Gangwon',
    '충북': 'Chungbuk',
    '충남': 'Chungnam',
    '전북': 'Jeonbuk',
    '전남': 'Jeonnam',
    '경북': 'Gyeongbuk',
    '경남': 'Gyeongnam',
    '제주': 'Jeju'
}

# 각 한글 도시명을 영어 도시명으로 변환
english_cities = [city_mapping[city] for city in cities]
# Out:
# ['전체', '서울', '부산', '대구', '인천', '광주', '대전', '울산', '세종', '경기', '강원', '충북', '충남', '전북', '전남', '경북', '경남', '제주']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-e92145820964> in <cell line: 23>()
#      21
#      22 # 각 한글 도시명을 영어 도시명으로 변환
# ---> 23 english_cities = [city_mapping[city] for city in cities]
#
# <ipython-input-43-e92145820964> in <listcomp>(.0)
#      21
#      22 # 각 한글 도시명을 영어 도시명으로 변환
# ---> 23 english_cities = [city_mapping[city] for city in cities]
#
# KeyError: '전체'

# %%
# data = {
#     '레벨': ['레벨1', '레벨2', '레벨3', '레벨4'],
#     '경기_percentage': [0.009528, 0.011029, 0.029994, 0.020536],
#     '서울_percentage': [0.013473, 0.013349, 0.012489, 0.013218],


# df = pd.DataFrame(data)
level = ['All','Level1','Level2','Level3','Level4','Level5','etc','Not Known']
# 꺾은 선 그래프 그리기
sns.set(style="whitegrid")

plt.figure(figsize=(10, 6))

# sns.lineplot(x=level, y=f'{cities[0]}_percentage', data=df, marker='o', label='경기_percentage')
# sns.lineplot(x=level, y=f'{cities[1]}_percentage', data=df, marker='o', label='서울_percentage')
for i in range(len(cities)):
  sns.lineplot(x=level, y=f'{cities[i]}_percentage', data=df_0, marker='o', label=f'{english_cities[i]}_percentage')
plt.title('Whole Cities level percentage')
plt.xlabel('Levels')
plt.ylabel('Percentage')
plt.legend()
plt.show()

# %%
df_0.head(30)
# Out:
#    Unnamed: 0  서울_2022년_중증인원수  서울_percentage  부산_2022년_중증인원수  부산_percentage  \
# 0           0        990391.0       1.000000        211432.0       1.000000
# 1           1         11778.0       0.011892          3544.0       0.016762
# 2           2         58608.0       0.059177         16151.0       0.076389
# 3           3        405812.0       0.409749         88374.0       0.417978
# 4           4        387024.0       0.390779         79401.0       0.375539
# 5           5        127018.0       0.128250         23916.0       0.113114
# 6           6           144.0       0.000145            45.0       0.000213
# 7           7             7.0       0.000007             1.0       0.000005
#
#    대구_2022년_중증인원수  대구_percentage  인천_2022년_중증인원수  인천_percentage  \
# 0        174313.0       1.000000        361493.0       1.000000
# 1          2665.0       0.015289          5313.0       0.014697
# 2         14666.0       0.084136         18595.0       0.051439
# ...

# %%
df_18.head(30)
# Out:
#     행정구역(시군구)별     2022.12  2022.12.1  2022.12.2   2023.10  2023.10.1  \
# 0   행정구역(시군구)별    총인구수 (명)  남자인구수 (명)  여자인구수 (명)  총인구수 (명)  남자인구수 (명)
# 1           전국  51439038.0   25636951   25802087  51354226   25582773
# 2        서울특별시   9428372.0    4570048    4858324   9400249    4548150
# 3        부산광역시   3317812.0    1619915    1697897   3298213    1608156
# 4        대구광역시   2363691.0    1162865    1200826   2376978    1168087
# 5        인천광역시   2967314.0    1485175    1482139   2990276    1495744
# 6        광주광역시   1431050.0     707299     723751   1421760     702121
# 7        대전광역시   1446072.0     721245     724827   1443965     720207
# 8        울산광역시   1110663.0     570368     540295   1104031     567309
# 9      세종특별자치시    383591.0     191389     192202    386079     192299
# 10         경기도  13589432.0    6839276    6750156  13627840    6855616
# 11     강원특별자치도   1536498.0     772947     763551   1529500     769433
# ...

# %%
df_18['2022.12'][1:] = df_18['2022.12'][1:].astype(str).str.replace(',', '').astype(float)
df_18 = df_18.drop(0)
df_18.head(30)
# Out:
#    행정구역(시군구)별     2022.12 2022.12.1 2022.12.2   2023.10 2023.10.1 2023.10.2
# 1          전국  51439038.0  25636951  25802087  51354226  25582773  25771453
# 2       서울특별시   9428372.0   4570048   4858324   9400249   4548150   4852099
# 3       부산광역시   3317812.0   1619915   1697897   3298213   1608156   1690057
# 4       대구광역시   2363691.0   1162865   1200826   2376978   1168087   1208891
# 5       인천광역시   2967314.0   1485175   1482139   2990276   1495744   1494532
# 6       광주광역시   1431050.0    707299    723751   1421760    702121    719639
# 7       대전광역시   1446072.0    721245    724827   1443965    720207    723758
# 8       울산광역시   1110663.0    570368    540295   1104031    567309    536722
# 9     세종특별자치시    383591.0    191389    192202    386079    192299    193780
# 10        경기도  13589432.0   6839276   6750156  13627840   6855616   6772224
# 11    강원특별자치도   1536498.0    772947    763551   1529500    769433    760067
# ...

# %%
df_0.drop('인구대비 중증비율', axis = 1)
# Out:
#    Unnamed: 0  서울_2022년_중증인원수  서울_percentage  부산_2022년_중증인원수  부산_percentage  \
# 0           0        990391.0       1.000000        211432.0       1.000000
# 1           1         11778.0       0.011892          3544.0       0.016762
# 2           2         58608.0       0.059177         16151.0       0.076389
# 3           3        405812.0       0.409749         88374.0       0.417978
# 4           4        387024.0       0.390779         79401.0       0.375539
# 5           5        127018.0       0.128250         23916.0       0.113114
# 6           6           144.0       0.000145            45.0       0.000213
# 7           7             7.0       0.000007             1.0       0.000005
#
#    대구_2022년_중증인원수  대구_percentage  인천_2022년_중증인원수  인천_percentage  \
# 0        174313.0       1.000000        361493.0       1.000000
# 1          2665.0       0.015289          5313.0       0.014697
# 2         14666.0       0.084136         18595.0       0.051439
# ...

# %%
## 이제, 전체 인구비율 중증환자의 비율을 보고싶다.
for i in range(len(cities)):
  # print(df_18['2022.12'].iloc[1])
  df_0[f'{cities[i]} 전체인구비율 대비 중증인원수'] = df_0[f'{cities[i]}_2022년_중증인원수'] / df_18['2022.12'].iloc[i+1]
  # print(df_0['서울_2022년_중증인원수'])

# %

# %%
df_0.head(30)
# Out:
#    Unnamed: 0  서울_2022년_중증인원수  서울_percentage  부산_2022년_중증인원수  부산_percentage  \
# 0           0        990391.0       1.000000        211432.0       1.000000
# 1           1         11778.0       0.011892          3544.0       0.016762
# 2           2         58608.0       0.059177         16151.0       0.076389
# 3           3        405812.0       0.409749         88374.0       0.417978
# 4           4        387024.0       0.390779         79401.0       0.375539
# 5           5        127018.0       0.128250         23916.0       0.113114
# 6           6           144.0       0.000145            45.0       0.000213
# 7           7             7.0       0.000007             1.0       0.000005
#
#    대구_2022년_중증인원수  대구_percentage  인천_2022년_중증인원수  인천_percentage  \
# 0        174313.0       1.000000        361493.0       1.000000
# 1          2665.0       0.015289          5313.0       0.014697
# 2         14666.0       0.084136         18595.0       0.051439
# ...

# %%
df_T = df_0.T
df_T.to_csv("/content/drive/MyDrive/Bigdata/N_data/중증환자지역별percentage")

# %%
df_T.head(60)
# Out:
#                             0         1         2         3         4  \
# Unnamed: 0                  0         1         2         3         4
# 서울_2022년_중증인원수       990391.0   11778.0   58608.0  405812.0  387024.0
# 서울_percentage             1.0  0.011892  0.059177  0.409749  0.390779
# 부산_2022년_중증인원수       211432.0    3544.0   16151.0   88374.0   79401.0
# 부산_percentage             1.0  0.016762  0.076389  0.417978  0.375539
# 대구_2022년_중증인원수       174313.0    2665.0   14666.0   99820.0   52970.0
# 대구_percentage             1.0  0.015289  0.084136  0.572648  0.303879
# 인천_2022년_중증인원수       361493.0    5313.0   18595.0  153342.0  141123.0
# 인천_percentage             1.0  0.014697  0.051439  0.424191  0.390389
# 광주_2022년_중증인원수       122758.0     953.0    5957.0   52825.0   50616.0
# 광주_percentage             1.0  0.007763  0.048526  0.430318  0.412323
# 대전_2022년_중증인원수       128558.0    1946.0    7698.0   49894.0   54186.0
# ...

# %%
print(df_T.columns)
# Out:
# RangeIndex(start=0, stop=8, step=1)

# %% [markdown]
# 이 그래프에, 중증도 4의 데이터도 함께 plot 하면 좋을듯.
#
# 그렇게 하면, 더 잘보일듯.

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt

# 데이터프레임 전치
# df_T = df_0.transpose()
# print(df_T.head(30))
# print(df_T.columns)
#
# level = ['All', 'Level1', 'Level2', 'Level3', 'Level4', 'Level5', 'etc', 'Not Known']

sns.set(style="whitegrid")

plt.figure(figsize=(10, 6))

# for i in range(len(cities)):
print(df_T.loc[f'{cities[i]} 전체인구비율 대비 중증인원수',0])
for i in range(len(cities)):
  print(cities[i])
  print(english_cities[i])
  sns.lineplot(x=english_cities, y=df_T.loc['서울 전체인구비율 대비 중증인원수':, 0])
  sns.lineplot(x=english_cities, y=df_T.loc['서울 전체인구비율 대비 중증인원수':, 1])

plt.title('Number of Severe Cases Relative to the Total Population, Level1')
plt.xlabel('Levels')
plt.xticks(rotation=45)
plt.ylabel('Percentage')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()
# Out:
# 0.17586878593368221
# 서울
# Seoul
# 부산
# Busan
# 대구
# Daegu
# 인천
# Incheon
# 광주
# Gwangju
# 대전
# Daejeon
# 울산
# Ulsan
# 세종
# Sejong
# 경기
# Gyeonggi
# 강원
# Gangwon
# 충북
# Chungbuk
# 충남
# Chungnam
# 전북
# Jeonbuk
# 전남
# Jeonnam
# 경북
# Gyeongbuk
# 경남
# Gyeongnam
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 제주
# Jeju

# %%
T# data = {
#     '레벨': ['레벨1', '레벨2', '레벨3', '레벨4'],
#     '경기_percentage': [0.009528, 0.011029, 0.029994, 0.020536],
#     '서울_percentage': [0.013473, 0.013349, 0.012489, 0.013218],


# df = pd.DataFrame(data)
level = ['All','Level1','Level2','Level3','Level4','Level5','etc','Not Known']
# 꺾은 선 그래프 그리기
sns.set(style="whitegrid")

plt.figure(figsize=(10, 6))

# sns.lineplot(x=level, y=f'{cities[0]}_percentage', data=df, marker='o', label='경기_percentage')
# sns.lineplot(x=level, y=f'{cities[1]}_percentage', data=df, marker='o', label='서울_percentage')
for i in range(len(cities)):
  sns.lineplot(x=level, y=f'{cities[i]} 전체인구비율 대비 중증인원수', data=df_0, label=f'{english_cities[i]}_percentage')
plt.title('Whole Cities percentage')
plt.xlabel('Levels')
plt.ylabel('Percentage')
plt.legend()
plt.show()

# %% [markdown]
# ## Q2 중증도를 보았을때, 병상갯수가 차이가 나는가?

# %%
# 중증환자수 가 해를 거듭할수록 늘어나는가?
# 그렇다면, 병상갯수는 늘어나는가? -> 잘 따라가고 있는가?
#

# %%
df_19 = pd.read_excel("/content/drive/MyDrive/Bigdata/Data/Data_1/응급의료기관+세부+병상+현황+-+시도별,+연도별.csv")

# %%
df_19.head(30)
# Out:
#                                                    No   분류     2022년  \
# 0                                                  No   분류  권역응급의료센터
# 1                                                  No   분류  응급전용중환자실
# 2                                                  No   분류         개
# 3                                                  No   분류       원자료
# 4                                                   1   전체       827
# 5                                                   2   서울       140
# 6                                                   3   부산        20
# 7                                                   4   대구        40
# 8                                                   5   인천        42
# 9                                                   6   광주        42
# 10                                                  7   대전        41
# 11                                                  8   울산        20
# 12                                                  9   세종       NaN
# ...

# %%
df_19.drop(22,axis = 0)
df_19 = df_19.fillna(0)
df_19.head(30)
# Out:
#                                                    No  분류     2022년   2022년.1  \
# 0                                                  No  분류  권역응급의료센터  권역응급의료센터
# 1                                                  No  분류  응급전용중환자실   응급전용입원실
# 2                                                  No  분류         개         개
# 3                                                  No  분류       원자료       원자료
# 4                                                   1  전체       827     1,384
# 5                                                   2  서울       140       218
# 6                                                   3  부산        20        36
# 7                                                   4  대구        40        74
# 8                                                   5  인천        42        66
# 9                                                   6  광주        42        60
# 10                                                  7  대전        41        61
# ...
