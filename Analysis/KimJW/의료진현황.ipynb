# %%
import numpy as np  # Import NumPy for handling numerical operations
import pandas as pd  # Import Pandas for data manipulation and analysis
import warnings  # Import Warnings to suppress unnecessary warnings

# Suppress warning messages
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
import seaborn
from matplotlib import rc
import os
rc('font', family='AppleGothic')

plt.rcParams['axes.unicode_minus'] = False

# %%
df = pd.read_excel("/Users/stone/Desktop/필요/4_2/BigData/팀플/데이터/12.7/응급의료기관+응급실+전담+의료진+현황+-+기관유형별,+시도별,+연도별.csv")

# %%
df_3 = pd.read_excel("/Users/stone/Desktop/필요/4_2/BigData/팀플/데이터/12.7/응급의학전문의+및+응급의학전공의+현황+-+시도별,+연도별.csv")

# %%
df_1 = pd.DataFrame()

# %%
df.head(30)
# Out:
#                                                    No    분류      분류.1  \
# 0                                                  No    분류        분류
# 1                                                  No    분류        분류
# 2                                                  No    분류        분류
# 3                                                  No    분류        분류
# 4                                                   1    전체        전체
# 5                                                   2  기관유형  권역응급의료센터
# 6                                                   3  기관유형  전문응급의료센터
# 7                                                   4  기관유형  지역응급의료센터
# 8                                                   5  기관유형  지역응급의료기관
# 9                                                   6    서울        서울
# 10                                                  7    부산        부산
# 11                                                  8    대구        대구
# 12                                                  9    인천        인천
# 13                                                 10    광주        광주
# 14                                                 11    대전        대전
# 15                                                 12    울산        울산
# 16                                                 13    세종        세종
# 17                                                 14    경기        경기
# 18                                                 15    강원        강원
# 19                                                 16    충북        충북
# 20                                                 17    충남        충남
# 21                                                 18    전북        전북
# 22                                                 19    전남        전남
# 23                                                 20    경북        경북
# 24                                                 21    경남        경남
# 25                                                 22    제주        제주
# 26      [출처] 응급의료 통계연보\n[정의]\n- 응급의료기관 평가결과를 근거로 작...   NaN       NaN
#
#       2021년    2021년.1  2021년.2       2021년.3       2021년.4    2020년  \
# 0     응급실전담      응급실전담    응급실전담  응급의료기관 1개소 당  응급의료기관 1개소 당    응급실전담
# 1     전문의 수  응급의학전문의 수    간호사 수     응급의학전문의 수         간호사 수    전문의 수
# 2         명          명        명             명             명        명
# 3       원자료        원자료      원자료           원자료           원자료      원자료
# 4   2,068.9    1,622.9  7,967.7           4.2          20.4  1,816.5
# 5     435.9      380.2  1,995.3            10          52.5    377.7
# 6       NaN        NaN      NaN           NaN           NaN      NaN
# 7     949.5      857.6  3,690.1           6.8          29.1    793.3
# 8     683.5      385.1  2,282.4           1.7          10.1    645.5
# 9     349.3      311.9  1,590.7           6.8          34.6    294.5
# 10    128.8         88    556.5           3.1          19.9    111.5
# 11     83.6       60.6    388.8           3.8          24.3     61.3
# 12    125.4      110.7    452.4           5.8          23.8    116.9
# 13     93.9       83.7    348.6           4.2          17.4     80.1
# 14     54.4       44.4    257.5           4.4          25.8     59.1
# 15     36.2       30.2    164.8           4.3          23.5     30.4
# 16     19.7       10.8     36.4           5.4          18.2        3
# 17    411.8      364.7  1,575.5             6          25.8    369.6
# 18     92.5       56.5    306.2           2.6          13.9     85.5
# 19     66.9       47.3    220.1           3.4          15.7     69.3
# 20     87.3       61.1    230.9           4.1          15.4       80
# 21     94.6       64.7    305.8           3.4          16.1     79.3
# 22     99.1       51.8      383           1.4          10.1     90.7
# 23    129.2         95    407.2           3.1          13.1    125.2
# 24    149.5       99.1    602.5           2.7          16.3    116.2
# 25     46.6       42.6    140.8           7.1          23.5     43.9
# 26      NaN        NaN      NaN           NaN           NaN      NaN
#
#       2020년.1  ...    2018년    2018년.1  2018년.2       2018년.3       2018년.4  \
# 0       응급실전담  ...    응급실전담      응급실전담    응급실전담  응급의료기관 1개소 당  응급의료기관 1개소 당
# 1   응급의학전문의 수  ...    전문의 수  응급의학전문의 수    간호사 수     응급의학전문의 수         간호사 수
# 2           명  ...        명          명        명             명             명
# 3         원자료  ...      원자료        원자료      원자료           원자료           원자료
# 4     1,444.3  ...  1,744.9    1,337.8  7,057.1           3.3          17.6
# 5       328.2  ...    364.2      317.2  1,716.6           8.6          47.7
# 6         NaN  ...      NaN        NaN      NaN           NaN           NaN
# 7       729.1  ...    698.3      632.5  2,970.9           5.5          25.6
# 8         387  ...    682.4      388.1  2,369.6           1.6           9.5
# 9       270.8  ...    284.7      259.2  1,420.8           5.4          29.6
# 10       76.5  ...    101.4       66.6    486.7           2.4          17.4
# 11       40.9  ...     52.6         37    281.9           3.1          23.5
# 12      101.1  ...    124.1      100.2    424.7           4.8          20.2
# 13       70.4  ...     73.5       64.2    304.7           3.2          15.2
# 14       48.4  ...     55.8       44.1    247.4           4.4          24.7
# 15         24  ...     34.3       24.1    166.4           2.4          16.6
# 16        2.7  ...      NaN        NaN      NaN           NaN           NaN
# 17      329.6  ...    327.5      285.3  1,337.6           4.5          20.9
# 18       54.3  ...     71.9       48.5    283.4           2.2          12.9
# 19       46.6  ...       56       37.1    192.2           2.5          12.8
# 20       59.7  ...     79.2       56.1    213.3           3.5          13.3
# 21       60.7  ...     95.2       65.2      293             3          13.3
# 22       47.4  ...     93.3       47.1    357.3           1.2           9.4
# 23       93.2  ...    137.7       90.5    395.7           2.8          12.4
# 24       77.7  ...    114.5       73.2    531.7             2          14.4
# 25       40.2  ...     43.2       39.4    120.3           6.6            20
# 26        NaN  ...      NaN        NaN      NaN           NaN           NaN
#
#     2017년    2017년.1 2017년.2       2017년.3       2017년.4
# 0   응급실전담      응급실전담   응급실전담  응급의료기관 1개소 당  응급의료기관 1개소 당
# 1   전문의 수  응급의학전문의 수   간호사 수     응급의학전문의 수         간호사 수
# 2       명          명       명             명             명
# 3     원자료        원자료     원자료           원자료           원자료
# 4   1,629      1,228   6,889             3          16.6
# 5     323        281   1,639           7.8          45.5
# 6     NaN        NaN     NaN           NaN           NaN
# 7     658        588   2,849           5.1          24.6
# 8     648        359   2,401           1.4           9.1
# 9     279        244   1,383           4.8          27.1
# 10     86         61     498             2          16.6
# 11     56         34     288           2.3          19.2
# 12    107         88     409           4.2          19.5
# 13     70         65     300           3.1          14.3
# 14     49         39     241           3.9          24.1
# 15     32         22     162           2.2          16.2
# 16      2        NaN       5           NaN             5
# 17    311        262   1,277             4          19.6
# 18     60         44     264           2.1          12.6
# 19     53         33     196           2.2          13.1
# 20     73         50     211           2.9          12.4
# 21     90         57     289           2.6          13.1
# 22     93         43     370             1             9
# 23    119         80     379           2.5          11.8
# 24    111         71     503           1.9          13.2
# 25     38         35     114           5.8            19
# 26    NaN        NaN     NaN           NaN           NaN
#
# [27 rows x 28 columns]

# %%
years1 = ['2017년', '2018년', '2019년', '2020년', '2021년']
years2 = ['2017년.1', '2018년.1', '2019년.1', '2020년.1', '2021년.1']
years3 = ['2017년.2', '2018년.2', '2019년.2', '2020년.2', '2021년.2']
years4 = ['2017년.4', '2018년.4', '2019년.4', '2020년.4', '2021년.4']
for i in years1:
    df_1[i] = df[i]
df_1['분류'] = df['분류']

cities = [
    '서울', '부산', '대구', '인천', '광주', '대전', '울산',
    '세종', '경기', '강원', '충북', '충남', '전북', '전남',
    '경북', '경남', '제주'
]

# %%
for i in years2:
    df_1[i] = df[i]

# %%
for i in years3:
    df_1[i] = df[i]
df_1['분류'] = df['분류']

for j in years4:
    df_1[j] = df_3[j]

# %%
df_1.head(30)
# Out:
#     2017년   2018년   2019년   2020년   2021년    분류    2017년.1    2018년.1  \
# 0   응급실전담   응급실전담   응급실전담   응급실전담   응급실전담    분류      응급실전담      응급실전담
# 1   전문의 수   전문의 수   전문의 수   전문의 수   전문의 수    분류  응급의학전문의 수  응급의학전문의 수
# 2       명       명       명       명       명    분류          명          명
# 3     원자료     원자료     원자료     원자료     원자료    분류        원자료        원자료
# 4    1629  1744.9  1820.2  1816.5  2068.9    전체       1228     1337.8
# 5     323   364.2   364.8   377.7   435.9  기관유형        281      317.2
# 6       0       0       0       0       0  기관유형          0          0
# 7     658   698.3   796.2   793.3   949.5  기관유형        588      632.5
# 8     648   682.4   659.1   645.5   683.5  기관유형        359      388.1
# 9     279   284.7   298.1   294.5   349.3    서울        244      259.2
# 10     86   101.4   108.1   111.5   128.8    부산         61       66.6
# 11     56    52.6      58    61.3    83.6    대구         34         37
# 12    107   124.1   122.4   116.9   125.4    인천         88      100.2
# 13     70    73.5    80.3    80.1    93.9    광주         65       64.2
# 14     49    55.8    59.6    59.1    54.4    대전         39       44.1
# 15     32    34.3    31.1    30.4    36.2    울산         22       24.1
# 16      2       0       0       3    19.7    세종          0          0
# 17    311   327.5   356.1   369.6   411.8    경기        262      285.3
# 18     60    71.9    76.1    85.5    92.5    강원         44       48.5
# 19     53      56    64.6    69.3    66.9    충북         33       37.1
# 20     73    79.2    80.4      80    87.3    충남         50       56.1
# 21     90    95.2    92.4    79.3    94.6    전북         57       65.2
# 22     93    93.3    91.4    90.7    99.1    전남         43       47.1
# 23    119   137.7   139.6   125.2   129.2    경북         80       90.5
# 24    111   114.5   119.1   116.2   149.5    경남         71       73.2
# 25     38    43.2    42.9    43.9    46.6    제주         35       39.4
# 26      0       0       0       0       0   NaN          0          0
#
#       2019년.1    2020년.1  ... 2017년.2  2018년.2  2019년.2  2020년.2  2021년.2  \
# 0       응급실전담      응급실전담  ...   응급실전담    응급실전담    응급실전담    응급실전담    응급실전담
# 1   응급의학전문의 수  응급의학전문의 수  ...   간호사 수    간호사 수    간호사 수    간호사 수    간호사 수
# 2           명          명  ...       명        명        명        명        명
# 3         원자료        원자료  ...     원자료      원자료      원자료      원자료      원자료
# 4      1416.7     1444.3  ...   6,889  7,057.1    7,240  7,211.9  7,967.7
# 5       317.8      328.2  ...   1,639  1,716.6  1,694.7  1,775.2  1,995.3
# 6           0          0  ...     NaN      NaN      NaN      NaN      NaN
# 7       720.3      729.1  ...   2,849  2,970.9  3,233.2  3,165.3  3,690.1
# 8       378.7        387  ...   2,401  2,369.6    2,312  2,271.4  2,282.4
# 9       265.4      270.8  ...   1,383  1,420.8  1,447.6  1,478.5  1,590.7
# 10       72.2       76.5  ...     498    486.7    497.7    493.9    556.5
# 11       41.3       40.9  ...     288    281.9    313.7      309    388.8
# 12       98.9      101.1  ...     409    424.7    422.7    429.6    452.4
# 13       69.6       70.4  ...     300    304.7    308.4    319.4    348.6
# 14       46.3       48.4  ...     241    247.4    245.9    249.4    257.5
# 15       24.8         24  ...     162    166.4    163.8    155.9    164.8
# 16          0        2.7  ...       5      NaN      NaN      7.3     36.4
# 17        314      329.6  ...   1,277  1,337.6  1,383.8  1,405.5  1,575.5
# 18       51.5       54.3  ...     264    283.4    294.6    296.8    306.2
# 19       43.1       46.6  ...     196    192.2      200      210    220.1
# 20       58.5       59.7  ...     211    213.3      224    222.4    230.9
# 21       68.8       60.7  ...     289      293    297.5    210.1    305.8
# 22       46.5       47.4  ...     370    357.3      363      358      383
# 23       94.6       93.2  ...     379    395.7    411.5    405.9    407.2
# 24       81.3       77.7  ...     503    531.7    540.6    531.3    602.5
# 25         40       40.2  ...     114    120.3    125.4      129    140.8
# 26          0          0  ...     NaN      NaN      NaN      NaN      NaN
#
#       2017년.4    2018년.4    2019년.4    2020년.4    2021년.4
# 0   응급의학전공의 수  응급의학전공의 수  응급의학전공의 수  응급의학전공의 수  응급의학전공의 수
# 1           계          계          계          계          계
# 2           명          명          명          명          명
# 3         원자료        원자료        원자료        원자료        원자료
# 4         617        630        626        623        623
# 5         212        213        221        213        204
# 6          35         33         27         28         25
# 7          31         33         37         37         35
# 8          35         36         39         42         45
# 9          22         23         23         24         24
# 10         25         26         27         27         28
# 11          9          9          6          7          9
# 12        NaN        NaN        NaN        NaN        NaN
# 13        131        136        128        138        137
# 14         31         34         32         30         27
# 15         13         12         11         12         14
# 16         15         14         18         15         18
# 17         14         15         13         11         13
# 18          7          8          8          4          4
# 19         11         13         11         12         14
# 20         18         16         18         16         18
# 21          8          9          7          7          8
# 22        NaN        NaN        NaN        NaN        NaN
# 23        NaN        NaN        NaN        NaN        NaN
# 24        NaN        NaN        NaN        NaN        NaN
# 25        NaN        NaN        NaN        NaN        NaN
# 26        NaN        NaN        NaN        NaN        NaN
#
# [27 rows x 21 columns]

# %%
df_1.fillna(0, inplace=True)
df_1.replace(',', '', regex=True, inplace=True)

# %%
text1 = "응급실 전담 의료진 현황"

# %%
seoul_data = df_1.loc[9 + 0]
seoul_data.drop('분류',inplace=True)
seoul_data = seoul_data.astype(float)
plt.plot(seoul_data.index[~seoul_data.index.str.contains('\.')], seoul_data[seoul_data.index.str.endswith('.1')], marker='o', label='응급의학 전문의 수')

# 전문의 수에 대한 꺾은선 그래프 그리기
plt.plot(seoul_data.index[~seoul_data.index.str.contains('\.')], seoul_data[~seoul_data.index.str.contains('\.')], marker='o', label='전문의 수')

# 간호사 수에 대한 꺾은선 그래프 그리기
plt.plot(seoul_data.index[~seoul_data.index.str.contains('\.')], seoul_data[seoul_data.index.str.endswith('.2')], marker='o', label='간호사 수')
# plt.plot(seoul_data.index[~seoul_data.index.str.contains('\.')], seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='간호사 수')

# for idx, value in seoul_data.items():
#     plt.text(idx, value, f'{value:.1f}', ha='center', va='bottom')

plt.title(f'{cities[0]}'+text1)
plt.xlabel('년도')
plt.ylabel('명')
plt.legend()
plt.grid(True)
plt.show()

# %%
seoul_data = df_1.loc[9 + 1]
seoul_data.drop('분류',inplace=True)
seoul_data = seoul_data.astype(float)
plt.plot(seoul_data.index[~seoul_data.index.str.contains('\.')], seoul_data[seoul_data.index.str.endswith('.1')], marker='o', label='응급의학 전문의 수')

# 전문의 수에 대한 꺾은선 그래프 그리기
plt.plot(seoul_data.index[~seoul_data.index.str.contains('\.')], seoul_data[~seoul_data.index.str.contains('\.')], marker='o', label='전문의 수')

# 간호사 수에 대한 꺾은선 그래프 그리기
plt.plot(seoul_data.index[~seoul_data.index.str.contains('\.')], seoul_data[seoul_data.index.str.endswith('.2')], marker='o', label='간호사 수')
# for idx, value in seoul_data.items():
#     plt.text(idx, value, f'{value:.1f}', ha='center', va='bottom')

plt.title(f'{cities[1]}'+text1)
plt.xlabel('년도')
plt.ylabel('명')
plt.legend()
plt.grid(True)
plt.show()

# %%
seoul_data = df_1.loc[9 + 2]
seoul_data.drop('분류',inplace=True)
seoul_data = seoul_data.astype(float)
plt.plot(seoul_data.index[~seoul_data.index.str.contains('\.')], seoul_data[seoul_data.index.str.endswith('.1')], marker='o', label='응급의학 전문의 수')

# 전문의 수에 대한 꺾은선 그래프 그리기
plt.plot(seoul_data.index[~seoul_data.index.str.contains('\.')], seoul_data[~seoul_data.index.str.contains('\.')], marker='o', label='전문의 수')

# 간호사 수에 대한 꺾은선 그래프 그리기
plt.plot(seoul_data.index[~seoul_data.index.str.contains('\.')], seoul_data[seoul_data.index.str.endswith('.2')], marker='o', label='간호사 수')
# for idx, value in seoul_data.items():
#     plt.text(idx, value, f'{value:.1f}', ha='center', va='bottom')

plt.title(f'{cities[2]}'+text1)
plt.xlabel('년도')
plt.ylabel('명')
plt.legend()
plt.grid(True)
plt.show()

# %%
seoul_data = df_1.loc[9 + 3]
seoul_data.drop('분류',inplace=True)
seoul_data = seoul_data.astype(float)
plt.plot(seoul_data.index[~seoul_data.index.str.contains('\.')], seoul_data[seoul_data.index.str.endswith('.1')], marker='o', label='응급의학 전문의 수')

# 전문의 수에 대한 꺾은선 그래프 그리기
plt.plot(seoul_data.index[~seoul_data.index.str.contains('\.')], seoul_data[~seoul_data.index.str.contains('\.')], marker='o', label='전문의 수')

# 간호사 수에 대한 꺾은선 그래프 그리기
plt.plot(seoul_data.index[~seoul_data.index.str.contains('\.')], seoul_data[seoul_data.index.str.endswith('.2')], marker='o', label='간호사 수')
# for idx, value in seoul_data.items():
#     plt.text(idx, value, f'{value:.1f}', ha='center', va='bottom')

plt.title(f'{cities[3]}'+text1)
plt.xlabel('년도')
plt.ylabel('명')
plt.legend()
plt.grid(True)
plt.show()

# %%
seoul_data = df_1.loc[9 + 4]
seoul_data.drop('분류',inplace=True)
seoul_data = seoul_data.astype(float)
plt.plot(seoul_data.index[~seoul_data.index.str.contains('\.')], seoul_data[seoul_data.index.str.endswith('.1')], marker='o', label='응급의학 전문의 수')

# 전문의 수에 대한 꺾은선 그래프 그리기
plt.plot(seoul_data.index[~seoul_data.index.str.contains('\.')], seoul_data[~seoul_data.index.str.contains('\.')], marker='o', label='전문의 수')

# 간호사 수에 대한 꺾은선 그래프 그리기
plt.plot(seoul_data.index[~seoul_data.index.str.contains('\.')], seoul_data[seoul_data.index.str.endswith('.2')], marker='o', label='간호사 수')
# for idx, value in seoul_data.items():
#     plt.text(idx, value, f'{value:.1f}', ha='center', va='bottom')

plt.title(f'{cities[4]}'+text1)
plt.xlabel('년도')
plt.ylabel('명')
plt.legend()
plt.grid(True)
plt.show()

# %%
seoul_data = df_1.loc[9 + 5]
seoul_data.drop('분류',inplace=True)
seoul_data = seoul_data.astype(float)
plt.plot(seoul_data.index[~seoul_data.index.str.contains('\.')], seoul_data[seoul_data.index.str.endswith('.1')], marker='o', label='응급의학 전문의 수')

# 전문의 수에 대한 꺾은선 그래프 그리기
plt.plot(seoul_data.index[~seoul_data.index.str.contains('\.')], seoul_data[~seoul_data.index.str.contains('\.')], marker='o', label='전문의 수')

# 간호사 수에 대한 꺾은선 그래프 그리기
plt.plot(seoul_data.index[~seoul_data.index.str.contains('\.')], seoul_data[seoul_data.index.str.endswith('.2')], marker='o', label='간호사 수')
# for idx, value in seoul_data.items():
#     plt.text(idx, value, f'{value:.1f}', ha='center', va='bottom')

plt.title(f'{cities[5]}'+text1)
plt.xlabel('년도')
plt.ylabel('명')
plt.legend()
plt.grid(True)
plt.show()

# %%
seoul_data = df_1.loc[9 + 6]
seoul_data.drop('분류',inplace=True)
seoul_data = seoul_data.astype(float)
plt.plot(seoul_data.index[~seoul_data.index.str.contains('\.')], seoul_data[seoul_data.index.str.endswith('.1')], marker='o', label='응급의학 전문의 수')

# 전문의 수에 대한 꺾은선 그래프 그리기
plt.plot(seoul_data.index[~seoul_data.index.str.contains('\.')], seoul_data[~seoul_data.index.str.contains('\.')], marker='o', label='전문의 수')

# 간호사 수에 대한 꺾은선 그래프 그리기
plt.plot(seoul_data.index[~seoul_data.index.str.contains('\.')], seoul_data[seoul_data.index.str.endswith('.2')], marker='o', label='간호사 수')
# for idx, value in seoul_data.items():
#     plt.text(idx, value, f'{value:.1f}', ha='center', va='bottom')

plt.title(f'{cities[6]}' + text1)
plt.xlabel('년도')
plt.ylabel('명')
plt.legend()
plt.grid(True)
plt.show()

# %%
seoul_data = df_1.loc[9 + 7]
seoul_data.drop('분류',inplace=True)
seoul_data = seoul_data.astype(float)
plt.plot(seoul_data.index[~seoul_data.index.str.contains('\.')], seoul_data[seoul_data.index.str.endswith('.1')], marker='o', label='응급의학 전문의 수')

# 전문의 수에 대한 꺾은선 그래프 그리기
plt.plot(seoul_data.index[~seoul_data.index.str.contains('\.')], seoul_data[~seoul_data.index.str.contains('\.')], marker='o', label='전문의 수')

# 간호사 수에 대한 꺾은선 그래프 그리기
plt.plot(seoul_data.index[~seoul_data.index.str.contains('\.')], seoul_data[seoul_data.index.str.endswith('.2')], marker='o', label='간호사 수')
# for idx, value in seoul_data.items():
#     plt.text(idx, value, f'{value:.1f}', ha='center', va='bottom')

plt.title(f'{cities[7]}'+text1)
plt.xlabel('년도')
plt.ylabel('명')
plt.legend()
plt.grid(True)
plt.show()

# %%
seoul_data = df_1.loc[9 + 8]
seoul_data.drop('분류',inplace=True)
seoul_data = seoul_data.astype(float)
plt.plot(seoul_data.index[~seoul_data.index.str.contains('\.')], seoul_data[seoul_data.index.str.endswith('.1')], marker='o', label='응급의학 전문의 수')

# 전문의 수에 대한 꺾은선 그래프 그리기
plt.plot(seoul_data.index[~seoul_data.index.str.contains('\.')], seoul_data[~seoul_data.index.str.contains('\.')], marker='o', label='전문의 수')

# 간호사 수에 대한 꺾은선 그래프 그리기
plt.plot(seoul_data.index[~seoul_data.index.str.contains('\.')], seoul_data[seoul_data.index.str.endswith('.2')], marker='o', label='간호사 수')
# for idx, value in seoul_data.items():
#     plt.text(idx, value, f'{value:.1f}', ha='center', va='bottom')

plt.title(f'{cities[8]}'+text1)
plt.xlabel('년도')
plt.ylabel('명')
plt.legend()
plt.grid(True)
plt.show()

# %%
seoul_data = df_1.loc[9 + 9]
seoul_data.drop('분류',inplace=True)
seoul_data = seoul_data.astype(float)
plt.plot(seoul_data.index[~seoul_data.index.str.contains('\.')], seoul_data[seoul_data.index.str.endswith('.1')], marker='o', label='응급의학 전문의 수')

# 전문의 수에 대한 꺾은선 그래프 그리기
plt.plot(seoul_data.index[~seoul_data.index.str.contains('\.')], seoul_data[~seoul_data.index.str.contains('\.')], marker='o', label='전문의 수')

# 간호사 수에 대한 꺾은선 그래프 그리기
plt.plot(seoul_data.index[~seoul_data.index.str.contains('\.')], seoul_data[seoul_data.index.str.endswith('.2')], marker='o', label='간호사 수')
# for idx, value in seoul_data.items():
#     plt.text(idx, value, f'{value:.1f}', ha='center', va='bottom')

plt.title(f'{cities[9]}'+text1)
plt.xlabel('년도')
plt.ylabel('명')
plt.legend()
plt.grid(True)
plt.show()

# %%
seoul_data = df_1.loc[9 + 10]
seoul_data.drop('분류',inplace=True)
seoul_data = seoul_data.astype(float)
plt.plot(seoul_data.index[~seoul_data.index.str.contains('\.')], seoul_data[seoul_data.index.str.endswith('.1')], marker='o', label='응급의학 전문의 수')

# 전문의 수에 대한 꺾은선 그래프 그리기
plt.plot(seoul_data.index[~seoul_data.index.str.contains('\.')], seoul_data[~seoul_data.index.str.contains('\.')], marker='o', label='전문의 수')

# 간호사 수에 대한 꺾은선 그래프 그리기
plt.plot(seoul_data.index[~seoul_data.index.str.contains('\.')], seoul_data[seoul_data.index.str.endswith('.2')], marker='o', label='간호사 수')
# for idx, value in seoul_data.items():
#     plt.text(idx, value, f'{value:.1f}', ha='center', va='bottom')

plt.title(f'{cities[10]}'+text1)
plt.xlabel('년도')
plt.ylabel('명')
plt.legend()
plt.grid(True)
plt.show()

# %%
seoul_data = df_1.loc[9 + 11]
seoul_data.drop('분류',inplace=True)
seoul_data = seoul_data.astype(float)
plt.plot(seoul_data.index[~seoul_data.index.str.contains('\.')], seoul_data[seoul_data.index.str.endswith('.1')], marker='o', label='응급의학 전문의 수')

# 전문의 수에 대한 꺾은선 그래프 그리기
plt.plot(seoul_data.index[~seoul_data.index.str.contains('\.')], seoul_data[~seoul_data.index.str.contains('\.')], marker='o', label='전문의 수')

# 간호사 수에 대한 꺾은선 그래프 그리기
plt.plot(seoul_data.index[~seoul_data.index.str.contains('\.')], seoul_data[seoul_data.index.str.endswith('.2')], marker='o', label='간호사 수')
# for idx, value in seoul_data.items():
#     plt.text(idx, value, f'{value:.1f}', ha='center', va='bottom')

plt.title(f'{cities[11]}'+text1)
plt.xlabel('년도')
plt.ylabel('명')
plt.legend()
plt.grid(True)
plt.show()

# %%
seoul_data = df_1.loc[9 + 12]
seoul_data.drop('분류',inplace=True)
seoul_data = seoul_data.astype(float)
plt.plot(seoul_data.index[~seoul_data.index.str.contains('\.')], seoul_data[seoul_data.index.str.endswith('.1')], marker='o', label='응급의학 전문의 수')

# 전문의 수에 대한 꺾은선 그래프 그리기
plt.plot(seoul_data.index[~seoul_data.index.str.contains('\.')], seoul_data[~seoul_data.index.str.contains('\.')], marker='o', label='전문의 수')

# 간호사 수에 대한 꺾은선 그래프 그리기
plt.plot(seoul_data.index[~seoul_data.index.str.contains('\.')], seoul_data[seoul_data.index.str.endswith('.2')], marker='o', label='간호사 수')
# for idx, value in seoul_data.items():
#     plt.text(idx, value, f'{value:.1f}', ha='center', va='bottom')

plt.title(f'{cities[12]}'+text1)
plt.xlabel('년도')
plt.ylabel('명')
plt.legend()
plt.grid(True)
plt.show()

# %%
seoul_data = df_1.loc[9 + 13]
seoul_data.drop('분류',inplace=True)
seoul_data = seoul_data.astype(float)
plt.plot(seoul_data.index[~seoul_data.index.str.contains('\.')], seoul_data[seoul_data.index.str.endswith('.1')], marker='o', label='응급의학 전문의 수')

# 전문의 수에 대한 꺾은선 그래프 그리기
plt.plot(seoul_data.index[~seoul_data.index.str.contains('\.')], seoul_data[~seoul_data.index.str.contains('\.')], marker='o', label='전문의 수')

# 간호사 수에 대한 꺾은선 그래프 그리기
plt.plot(seoul_data.index[~seoul_data.index.str.contains('\.')], seoul_data[seoul_data.index.str.endswith('.2')], marker='o', label='간호사 수')
# for idx, value in seoul_data.items():
#     plt.text(idx, value, f'{value:.1f}', ha='center', va='bottom')

plt.title(f'{cities[13]}'+text1)
plt.xlabel('년도')
plt.ylabel('명')
plt.legend()
plt.grid(True)
plt.show()

# %%
seoul_data = df_1.loc[9 + 14]
seoul_data.drop('분류',inplace=True)
seoul_data = seoul_data.astype(float)
plt.plot(seoul_data.index[~seoul_data.index.str.contains('\.')], seoul_data[seoul_data.index.str.endswith('.1')], marker='o', label='응급의학 전문의 수')

# 전문의 수에 대한 꺾은선 그래프 그리기
plt.plot(seoul_data.index[~seoul_data.index.str.contains('\.')], seoul_data[~seoul_data.index.str.contains('\.')], marker='o', label='전문의 수')

# 간호사 수에 대한 꺾은선 그래프 그리기
plt.plot(seoul_data.index[~seoul_data.index.str.contains('\.')], seoul_data[seoul_data.index.str.endswith('.2')], marker='o', label='간호사 수')
# for idx, value in seoul_data.items():
#     plt.text(idx, value, f'{value:.1f}', ha='center', va='bottom')

plt.title(f'{cities[14]}'+text1)
plt.xlabel('년도')
plt.ylabel('명')
plt.legend()
plt.grid(True)
plt.show()

# %%
seoul_data = df_1.loc[9 + 15]
seoul_data.drop('분류',inplace=True)
seoul_data = seoul_data.astype(float)
plt.plot(seoul_data.index[~seoul_data.index.str.contains('\.')], seoul_data[seoul_data.index.str.endswith('.1')], marker='o', label='응급의학 전문의 수')

# 전문의 수에 대한 꺾은선 그래프 그리기
plt.plot(seoul_data.index[~seoul_data.index.str.contains('\.')], seoul_data[~seoul_data.index.str.contains('\.')], marker='o', label='전문의 수')

# 간호사 수에 대한 꺾은선 그래프 그리기
plt.plot(seoul_data.index[~seoul_data.index.str.contains('\.')], seoul_data[seoul_data.index.str.endswith('.2')], marker='o', label='간호사 수')
# for idx, value in seoul_data.items():
#     plt.text(idx, value, f'{value:.1f}', ha='center', va='bottom')

plt.title(f'{cities[15]}'+text1)
plt.xlabel('년도')
plt.ylabel('명')
plt.legend()
plt.grid(True)
plt.show()

# %%
seoul_data = df_1.loc[9 + 16]
seoul_data.drop('분류',inplace=True)
seoul_data = seoul_data.astype(float)
plt.plot(seoul_data.index[~seoul_data.index.str.contains('\.')], seoul_data[seoul_data.index.str.endswith('.1')], marker='o', label='응급의학 전문의 수')

# 전문의 수에 대한 꺾은선 그래프 그리기
plt.plot(seoul_data.index[~seoul_data.index.str.contains('\.')], seoul_data[~seoul_data.index.str.contains('\.')], marker='o', label='전문의 수')

# 간호사 수에 대한 꺾은선 그래프 그리기
plt.plot(seoul_data.index[~seoul_data.index.str.contains('\.')], seoul_data[seoul_data.index.str.endswith('.2')], marker='o', label='간호사 수')
# for idx, value in seoul_data.items():
#     plt.text(idx, value, f'{value:.1f}', ha='center', va='bottom')

plt.title(f'{cities[16]}'+text1)
plt.xlabel('년도')
plt.ylabel('명')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # 응급의학전문의+및+응급의학전공의+현황

# %%
df_3 = pd.read_excel("/Users/stone/Desktop/필요/4_2/BigData/팀플/데이터/12.7/응급의학전문의+및+응급의학전공의+현황+-+시도별,+연도별.csv")
df_4 = pd.DataFrame()
df_3.head(30)
# Out:
#                                                    No   분류      2021년  \
# 0                                                  No   분류  응급의학전문의 수
# 1                                                  No   분류          계
# 2                                                  No   분류          명
# 3                                                  No   분류        원자료
# 4                                                   1   전체      2,316
# 5                                                   2   서울        936
# 6                                                   3   부산        108
# 7                                                   4   대구        119
# 8                                                   5   인천        115
# 9                                                   6   광주        102
# 10                                                  7   대전         91
# 11                                                  8   울산         22
# 12                                                  9   세종        NaN
# 13                                                 10   경기        323
# 14                                                 11   강원        131
# 15                                                 12   충북         23
# 16                                                 13   충남         83
# 17                                                 14   전북         84
# 18                                                 15   전남         32
# 19                                                 16   경북         56
# 20                                                 17   경남         71
# 21                                                 18   제주         20
# 22      [출처] 응급의료 통계연보\n[정의] \n- 응급의학전문의 수: 대한응급의학...  NaN        NaN
#
#       2021년.1    2021년.2             2021년.3    2021년.4    2021년.5    2021년.6  \
# 0   응급의학전문의 수  응급의학전문의 수           응급의학전문의 수  응급의학전공의 수  응급의학전공의 수  응급의학전공의 수
# 1          남자         여자  인구 십만 명당 응급의학전문의 수          계         남자         여자
# 2           명          명                   명          명          명          명
# 3         원자료        원자료                 원자료        원자료        원자료        원자료
# 4       2,017        299                 4.5        623        511        112
# 5         752        184                 9.8        204        157         47
# 6          98         10                 3.2         25         21          4
# 7         111          8                   5         35         31          4
# 8          98         17                 3.9         45         39          6
# 9          98          4                 7.1         24         24        NaN
# 10         87          4                 6.3         28         21          7
# 11         21          1                   2          9          9        NaN
# 12        NaN        NaN                 NaN        NaN        NaN        NaN
# 13        288         35                 2.4        137        114         23
# 14        126          5                 8.5         27         24          3
# 15         23        NaN                 1.4         14         13          1
# 16         76          7                 3.9         18         13          5
# 17         76          8                 4.7         13         12          1
# 18         32        NaN                 1.7          4          3          1
# 19         53          3                 2.1         14         13          1
# 20         62          9                 2.1         18         13          5
# 21         16          4                   3          8          4          4
# 22        NaN        NaN                 NaN        NaN        NaN        NaN
#
#                2021년.7  ...    2018년.6             2018년.7      2017년  \
# 0            응급의학전공의 수  ...  응급의학전공의 수           응급의학전공의 수  응급의학전문의 수
# 1   인구 십만 명당 응급의학전공의 수  ...         여자  인구 십만 명당 응급의학전공의 수          계
# 2                    명  ...          명                   명          명
# 3                  원자료  ...        원자료                 원자료        원자료
# 4                  1.2  ...         90                 1.2      1,704
# 5                  2.1  ...         42                 2.2        686
# 6                  0.7  ...        NaN                   1         71
# 7                  1.5  ...          1                 1.3         87
# 8                  1.5  ...          1                 1.2         90
# 9                  1.7  ...        NaN                 1.6         73
# 10                 1.9  ...          3                 1.7         63
# 11                 0.8  ...          2                 0.8         15
# 12                 NaN  ...        NaN                 NaN        NaN
# 13                   1  ...         22                   1        270
# 14                 1.8  ...          4                 2.2         85
# 15                 0.9  ...          2                 0.8         15
# 16                 0.8  ...          2                 0.7         58
# 17                 0.7  ...          1                 0.8         58
# 18                 0.2  ...          1                 0.4         30
# 19                 0.5  ...          2                 0.5         39
# 20                 0.5  ...          4                 0.5         48
# 21                 1.2  ...          3                 1.3         16
# 22                 NaN  ...        NaN                 NaN        NaN
#
#       2017년.1    2017년.2             2017년.3    2017년.4    2017년.5    2017년.6  \
# 0   응급의학전문의 수  응급의학전문의 수           응급의학전문의 수  응급의학전공의 수  응급의학전공의 수  응급의학전공의 수
# 1          남자         여자  인구 십만 명당 응급의학전문의 수          계         남자         여자
# 2           명          명                   명          명          명          명
# 3         원자료        원자료                 원자료        원자료        원자료        원자료
# 4       1,493        211                 3.3        617        530         87
# 5         552        134                   7        212        169         43
# 6          66          5                   2         35         35        NaN
# 7          83          4                 3.5         31         30          1
# 8          74         16                 3.1         35         33          2
# 9          71          2                   5         22         21          1
# 10         61          2                 4.2         25         23          2
# 11         15        NaN                 1.3          9          6          3
# 12        NaN        NaN                 NaN        NaN        NaN        NaN
# 13        244         26                 2.1        131        110         21
# 14         83          2                 5.5         31         28          3
# 15         15        NaN                 0.9         13         12          1
# 16         53          5                 2.7         15         13          2
# 17         52          6                 3.1         14         13          1
# 18         30        NaN                 1.6          7          7        NaN
# 19         37          2                 1.4         11         11        NaN
# 20         44          4                 1.4         18         12          6
# 21         13          3                 2.4          8          7          1
# 22        NaN        NaN                 NaN        NaN        NaN        NaN
#
#                2017년.7
# 0            응급의학전공의 수
# 1   인구 십만 명당 응급의학전공의 수
# 2                    명
# 3                  원자료
# 4                  NaN
# 5                  1.2
# 6                  2.2
# 7                    1
# 8                  1.3
# 9                  1.2
# 10                 1.5
# 11                 1.7
# 12                 0.8
# 13                 NaN
# 14                   1
# 15                   2
# 16                 0.8
# 17                 0.7
# 18                 0.8
# 19                 0.4
# 20                 0.4
# 21                 0.5
# 22                 NaN
#
# [23 rows x 42 columns]

# %%
years3 = ['2017년', '2018년', '2019년', '2020년', '2021년']
years4 = ['2017년.4', '2018년.4', '2019년.4', '2020년.4', '2021년.4']
df_4 = pd.DataFrame()
for i in years3:
    df_4[i] = df_3[i]
df_4['분류'] = df_3['분류']

cities = [
    '서울', '부산', '대구', '인천', '광주', '대전', '울산',
    '세종', '경기', '강원', '충북', '충남', '전북', '전남',
    '경북', '경남', '제주'
]
for j in years4:
    df_4[j] = df_3[j]
df_4['분류'] = df_3['분류']
df_4.fillna(0, inplace=True)
df_4.replace(',', '', regex=True, inplace=True)

# %%
text2 = "응급의학전문의 및 응급의학전공의 현황"

# %%
df_4.head(30)
# Out:
#         2017년      2018년      2019년      2020년      2021년  분류    2017년.4  \
# 0   응급의학전문의 수  응급의학전문의 수  응급의학전문의 수  응급의학전문의 수  응급의학전문의 수  분류  응급의학전공의 수
# 1           계          계          계          계          계  분류          계
# 2           명          명          명          명          명  분류          명
# 3         원자료        원자료        원자료        원자료        원자료  분류        원자료
# 4        1704       1843       2000       2168       2316  전체        617
# 5         686        753        810        870        936  서울        212
# 6          71         79         90        101        108  부산         35
# 7          87         90        103        110        119  대구         31
# 8          90        100        102        106        115  인천         35
# 9          73         78         84         95        102  광주         22
# 10         63         68         77         85         91  대전         25
# 11         15         17         20         21         22  울산          9
# 12          0          0          0          0          0  세종          0
# 13        270        288        295        301        323  경기        131
# 14         85         90        105        125        131  강원         31
# 15         15         18         20         21         23  충북         13
# 16         58         61         67         80         83  충남         15
# 17         58         60         73         81         84  전북         14
# 18         30         30         30         32         32  전남          7
# 19         39         41         48         56         56  경북         11
# 20         48         54         59         66         71  경남         18
# 21         16         16         17         18         20  제주          8
# 22          0          0          0          0          0   0          0
#
#       2018년.4    2019년.4    2020년.4    2021년.4
# 0   응급의학전공의 수  응급의학전공의 수  응급의학전공의 수  응급의학전공의 수
# 1           계          계          계          계
# 2           명          명          명          명
# 3         원자료        원자료        원자료        원자료
# 4         630        626        623        623
# 5         213        221        213        204
# 6          33         27         28         25
# 7          33         37         37         35
# 8          36         39         42         45
# 9          23         23         24         24
# 10         26         27         27         28
# 11          9          6          7          9
# 12          0          0          0          0
# 13        136        128        138        137
# 14         34         32         30         27
# 15         12         11         12         14
# 16         14         18         15         18
# 17         15         13         11         13
# 18          8          8          4          4
# 19         13         11         12         14
# 20         16         18         16         18
# 21          9          7          7          8
# 22          0          0          0          0

# %%
df_4.head(30)

# %%
df_4.head(30)
# Out:
#         2017년      2018년      2019년      2020년      2021년  분류    2017년.4  \
# 0   응급의학전문의 수  응급의학전문의 수  응급의학전문의 수  응급의학전문의 수  응급의학전문의 수  분류  응급의학전공의 수
# 1           계          계          계          계          계  분류          계
# 2           명          명          명          명          명  분류          명
# 3         원자료        원자료        원자료        원자료        원자료  분류        원자료
# 4        1704       1843       2000       2168       2316  전체        617
# 5         686        753        810        870        936  서울        212
# 6          71         79         90        101        108  부산         35
# 7          87         90        103        110        119  대구         31
# 8          90        100        102        106        115  인천         35
# 9          73         78         84         95        102  광주         22
# 10         63         68         77         85         91  대전         25
# 11         15         17         20         21         22  울산          9
# 12          0          0          0          0          0  세종          0
# 13        270        288        295        301        323  경기        131
# 14         85         90        105        125        131  강원         31
# 15         15         18         20         21         23  충북         13
# 16         58         61         67         80         83  충남         15
# 17         58         60         73         81         84  전북         14
# 18         30         30         30         32         32  전남          7
# 19         39         41         48         56         56  경북         11
# 20         48         54         59         66         71  경남         18
# 21         16         16         17         18         20  제주          8
# 22          0          0          0          0          0   0          0
#
#       2018년.4    2019년.4    2020년.4    2021년.4
# 0   응급의학전공의 수  응급의학전공의 수  응급의학전공의 수  응급의학전공의 수
# 1           계          계          계          계
# 2           명          명          명          명
# 3         원자료        원자료        원자료        원자료
# 4         630        626        623        623
# 5         213        221        213        204
# 6          33         27         28         25
# 7          33         37         37         35
# 8          36         39         42         45
# 9          23         23         24         24
# 10         26         27         27         28
# 11          9          6          7          9
# 12          0          0          0          0
# 13        136        128        138        137
# 14         34         32         30         27
# 15         12         11         12         14
# 16         14         18         15         18
# 17         15         13         11         13
# 18          8          8          4          4
# 19         13         11         12         14
# 20         16         18         16         18
# 21          9          7          7          8
# 22          0          0          0          0

# %%
import matplotlib.pyplot as plt

# 주어진 데이터
seoul_data = df_4.loc[5 +0]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[~seoul_data.index.str.contains('\.')], marker='o', label='응급의학전문의 수')

# 응급의학전공의 수 그래프
plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[0]} 응급의학전문의 수 및 응급의학전공의 수')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
import matplotlib.pyplot as plt

# 주어진 데이터
seoul_data = df_4.loc[5 + 1]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[~seoul_data.index.str.contains('\.')], marker='o', label='응급의학전문의 수')

# 응급의학전공의 수 그래프
plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[1]} 응급의학전문의 수 및 응급의학전공의 수')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
import matplotlib.pyplot as plt

# 주어진 데이터
seoul_data = df_4.loc[5 + 2]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[~seoul_data.index.str.contains('\.')], marker='o', label='응급의학전문의 수')

# 응급의학전공의 수 그래프
plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[2]} 응급의학전문의 수 및 응급의학전공의 수')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
import matplotlib.pyplot as plt

# 주어진 데이터
seoul_data = df_4.loc[5 + 3]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[~seoul_data.index.str.contains('\.')], marker='o', label='응급의학전문의 수')

# 응급의학전공의 수 그래프
plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[3]} 응급의학전문의 수 및 응급의학전공의 수')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
import matplotlib.pyplot as plt

# 주어진 데이터
seoul_data = df_4.loc[5 + 4]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[~seoul_data.index.str.contains('\.')], marker='o', label='응급의학전문의 수')

# 응급의학전공의 수 그래프
plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[4]} 응급의학전문의 수 및 응급의학전공의 수')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
import matplotlib.pyplot as plt

# 주어진 데이터
seoul_data = df_4.loc[5 + 5]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[~seoul_data.index.str.contains('\.')], marker='o', label='응급의학전문의 수')

# 응급의학전공의 수 그래프
plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[5]} 응급의학전문의 수 및 응급의학전공의 수')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
import matplotlib.pyplot as plt

# 주어진 데이터
seoul_data = df_4.loc[5 + 6]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[~seoul_data.index.str.contains('\.')], marker='o', label='응급의학전문의 수')

# 응급의학전공의 수 그래프
plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[6]} 응급의학전문의 수 및 응급의학전공의 수')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
# 주어진 데이터
seoul_data = df_4.loc[5 + 7]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[~seoul_data.index.str.contains('\.')], marker='o', label='응급의학전문의 수')

# 응급의학전공의 수 그래프
plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[7]} 응급의학전문의 수 및 응급의학전공의 수')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
import matplotlib.pyplot as plt

# 주어진 데이터
seoul_data = df_4.loc[5 + 8]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[~seoul_data.index.str.contains('\.')], marker='o', label='응급의학전문의 수')

# 응급의학전공의 수 그래프
plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[8]} 응급의학전문의 수 및 응급의학전공의 수')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
import matplotlib.pyplot as plt

# 주어진 데이터
seoul_data = df_4.loc[5 + 9]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[~seoul_data.index.str.contains('\.')], marker='o', label='응급의학전문의 수')

# 응급의학전공의 수 그래프
plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[9]} 응급의학전문의 수 및 응급의학전공의 수')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
import matplotlib.pyplot as plt

# 주어진 데이터
seoul_data = df_4.loc[5 + 10]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[~seoul_data.index.str.contains('\.')], marker='o', label='응급의학전문의 수')

# 응급의학전공의 수 그래프
plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[10]} 응급의학전문의 수 및 응급의학전공의 수')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
import matplotlib.pyplot as plt

# 주어진 데이터
seoul_data = df_4.loc[5 + 11]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[~seoul_data.index.str.contains('\.')], marker='o', label='응급의학전문의 수')

# 응급의학전공의 수 그래프
plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[11]} 응급의학전문의 수 및 응급의학전공의 수')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
import matplotlib.pyplot as plt

# 주어진 데이터
seoul_data = df_4.loc[5 + 12]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[~seoul_data.index.str.contains('\.')], marker='o', label='응급의학전문의 수')

# 응급의학전공의 수 그래프
plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[12]} 응급의학전문의 수 및 응급의학전공의 수')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
import matplotlib.pyplot as plt

# 주어진 데이터
seoul_data = df_4.loc[5 + 13]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[~seoul_data.index.str.contains('\.')], marker='o', label='응급의학전문의 수')

# 응급의학전공의 수 그래프
plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[13]} 응급의학전문의 수 및 응급의학전공의 수')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
import matplotlib.pyplot as plt

# 주어진 데이터
seoul_data = df_4.loc[5 + 14]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[~seoul_data.index.str.contains('\.')], marker='o', label='응급의학전문의 수')

# 응급의학전공의 수 그래프
plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[14]} 응급의학전문의 수 및 응급의학전공의 수')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
import matplotlib.pyplot as plt

# 주어진 데이터
seoul_data = df_4.loc[5 + 15]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[~seoul_data.index.str.contains('\.')], marker='o', label='응급의학전문의 수')

# 응급의학전공의 수 그래프
plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[15]} 응급의학전문의 수 및 응급의학전공의 수')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
import matplotlib.pyplot as plt

# 주어진 데이터
seoul_data = df_4.loc[5 + 16]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[~seoul_data.index.str.contains('\.')], marker='o', label='응급의학전문의 수')

# 응급의학전공의 수 그래프
plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[]} 응급의학전문의 수 및 응급의학전공의 수')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
df_5 = pd.read_excel("/Users/stone/Desktop/필요/4_2/BigData/팀플/데이터/12.7/전체+구급차+및+배치된+의료인력+현황+-+시도별,+연도별 (1).csv")
df_6 = pd.DataFrame()

# %%
df_5.head()
# Out:
#    No  분류   2021년 2021년.1 2021년.2            2021년.3 2021년.4   2021년.5  \
# 0  No  분류  전체 구급차  전체 구급차  전체 구급차             전체 구급차    탑승인력      탑승인력
# 1  No  분류       계      특수      일반  인구 십만 명당 전체 구급차 수       계  1급 응급구조사
# 2  No  분류       대       대       대                  대       명         명
# 3  No  분류     원자료     원자료     원자료                원자료     원자료       원자료
# 4   1  전체   7,569   3,823   3,746               14.7  21,667     7,332
#
#     2021년.6 2021년.7  ...   2018년.6 2018년.7   2017년 2017년.1 2017년.2  \
# 0      탑승인력    탑승인력  ...      탑승인력    탑승인력  전체 구급차  전체 구급차  전체 구급차
# 1  2급 응급구조사  의사/간호사  ...  2급 응급구조사  의사/간호사       계      특수      일반
# 2         명       명  ...         명       명       대       대       대
# 3       원자료     원자료  ...       원자료     원자료     원자료     원자료     원자료
# 4     3,734  10,601  ...     4,015  10,379   7,764   3,502   4,262
#
#              2017년.3 2017년.4   2017년.5   2017년.6 2017년.7
# 0             전체 구급차    탑승인력      탑승인력      탑승인력    탑승인력
# 1  인구 십만 명당 전체 구급차 수       계  1급 응급구조사  2급 응급구조사  의사/간호사
# 2                  대       명         명         명       명
# 3                원자료     원자료       원자료       원자료     원자료
# 4                 15  24,077     6,177     4,364  13,536
#
# [5 rows x 42 columns]

# %%
df_6.head()
# Out:
#     2017년   2018년   2019년   2020년   2021년  분류
# 0  전체 구급차  전체 구급차  전체 구급차  전체 구급차  전체 구급차  분류
# 1       계       계       계       계       계  분류
# 2       대       대       대       대       대  분류
# 3     원자료     원자료     원자료     원자료     원자료  분류
# 4   7,764   7,800   7,740   7,668   7,569  전체

# %%
years3 = ['2017년', '2018년', '2019년', '2020년', '2021년']
years4 = ['2017년.4', '2018년.4', '2019년.4', '2020년.4', '2021년.4']
df_6 = pd.DataFrame()
for i in years3:
    df_6[i] = df_5[i]
df_6['분류'] = df_5['분류']

# %%
df_6.fillna(0, inplace=True)
df_6.replace(',', '', regex=True, inplace=True)

# %%
import matplotlib.pyplot as plt

# 주어진 데이터
seoul_data = df_6.loc[4 + 0]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[~seoul_data.index.str.contains('\.')], marker='o', label='구급차')

# # 응급의학전공의 수 그래프
# plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[0]} 구급차수')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
import matplotlib.pyplot as plt

# 주어진 데이터
seoul_data = df_6.loc[4 + 1]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[~seoul_data.index.str.contains('\.')], marker='o', label='구급차')

# # 응급의학전공의 수 그래프
# plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[1]} 구급차수')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
import matplotlib.pyplot as plt

# 주어진 데이터
seoul_data = df_6.loc[4 + 2]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[~seoul_data.index.str.contains('\.')], marker='o', label='구급차')

# # 응급의학전공의 수 그래프
# plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[2]import matplotlib.pyplot as plt

# 주어진 데이터
seoul_data = df_6.loc[4 + 0]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[~seoul_data.index.str.contains('\.')], marker='o', label='구급차')

# # 응급의학전공의 수 그래프
# plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[0]} 구급차수')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()
} 구급차수')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
import matplotlib.pyplot as plt

# 주어진 데이터
seoul_data = df_6.loc[4 + 3]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[~seoul_data.index.str.contains('\.')], marker='o', label='구급차')

# # 응급의학전공의 수 그래프
# plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[3]} 구급차수')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
import matplotlib.pyplot as plt

# 주어진 데이터
seoul_data = df_6.loc[4 + 4]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[~seoul_data.index.str.contains('\.')], marker='o', label='구급차')

# # 응급의학전공의 수 그래프
# plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[4]} 구급차수')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
import matplotlib.pyplot as plt

# 주어진 데이터
seoul_data = df_6.loc[4 + 5]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[~seoul_data.index.str.contains('\.')], marker='o', label='구급차')

# # 응급의학전공의 수 그래프
# plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[5]} 구급차수')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
import matplotlib.pyplot as plt

# 주어진 데이터
seoul_data = df_6.loc[4 + 6]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[~seoul_data.index.str.contains('\.')], marker='o', label='구급차')

# # 응급의학전공의 수 그래프
# plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[6]} 구급차수')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
import matplotlib.pyplot as plt

# 주어진 데이터
seoul_data = df_6.loc[4 + 7]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[~seoul_data.index.str.contains('\.')], marker='o', label='구급차')

# # 응급의학전공의 수 그래프
# plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[7]} 구급차수')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
import matplotlib.pyplot as plt

# 주어진 데이터
seoul_data = df_6.loc[4 + 8]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[~seoul_data.index.str.contains('\.')], marker='o', label='구급차')

# # 응급의학전공의 수 그래프
# plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[8]} 구급차수')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
import matplotlib.pyplot as plt

# 주어진 데이터
seoul_data = df_6.loc[4 + 9]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[~seoul_data.index.str.contains('\.')], marker='o', label='구급차')

# # 응급의학전공의 수 그래프
# plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[9]} 구급차수')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
import matplotlib.pyplot as plt

# 주어진 데이터
seoul_data = df_6.loc[4 + 10]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[~seoul_data.index.str.contains('\.')], marker='o', label='구급차')

# # 응급의학전공의 수 그래프
# plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[10]} 구급차수')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
import matplotlib.pyplot as plt

# 주어진 데이터
seoul_data = df_6.loc[4 + 11]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[~seoul_data.index.str.contains('\.')], marker='o', label='구급차')

# # 응급의학전공의 수 그래프
# plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[11]} 구급차수')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
import matplotlib.pyplot as plt

# 주어진 데이터
seoul_data = df_6.loc[4 + 12]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[~seoul_data.index.str.contains('\.')], marker='o', label='구급차')

# # 응급의학전공의 수 그래프
# plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[12]} 구급차수')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
import matplotlib.pyplot as plt

# 주어진 데이터
seoul_data = df_6.loc[4 + 13]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[~seoul_data.index.str.contains('\.')], marker='o', label='구급차')

# # 응급의학전공의 수 그래프
# plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[13]} 구급차수')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
import matplotlib.pyplot as plt

# 주어진 데이터
seoul_data = df_6.loc[4 + 14]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[~seoul_data.index.str.contains('\.')], marker='o', label='구급차')

# # 응급의학전공의 수 그래프
# plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[14]} 구급차수')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
import matplotlib.pyplot as plt

# 주어진 데이터
seoul_data = df_6.loc[4 + 15]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[~seoul_data.index.str.contains('\.')], marker='o', label='구급차')

# # 응급의학전공의 수 그래프
# plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[15]} 구급차수')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
# 주어진 데이터
seoul_data = df_6.loc[4 + 16]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[~seoul_data.index.str.contains('\.')], marker='o', label='구급차')

# # 응급의학전공의 수 그래프
# plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[16]} 구급차수')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
df_7 = pd.DataFrame()
years3 = ['2017년', '2018년', '2019년', '2020년', '2021년']
years5 = ['2017년.5', '2018년.5', '2019년.5', '2020년.5', '2021년.5']
years6 = ['2017년.6', '2018년.6', '2019년.6','2020년.6', '2021년.6']
years7 = ['2017년.7', '2018년.7', '2019년.7', '2020년.7', '2021년.7']
df_7.fillna(0, inplace=True)
df_7.replace(',', '', regex=True, inplace=True)


for i in years3:
    df_7[i] = df_5[i]
df_7['분류'] = df_5['분류']

for i in years5:
    df_7[i] = df_5[i]
df_7['분류'] = df_5['분류']

for i in years6:
    df_7[i] = df_5[i]
df_7['분류'] = df_5['분류']

for i in years7:
    df_7[i] = df_5[i]
df_7['분류'] = df_5['분류']

# %%
df_7.head()
df_7.fillna(0, inplace=True)
df_7.replace(',', '', regex=True, inplace=True)

# %%
# 주어진 데이터
seoul_data = df_7.loc[4+0]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)
print(seoul_data)
# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[~seoul_data.index.str.contains('.7')], marker='o', label='구급차')

# # 응급의학전공의 수 그래프
# plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[]} 구급차수')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()
# Out:
# 2017년       7764.0
# 2018년       7800.0
# 2019년       7740.0
# 2020년       7668.0
# 2021년       7569.0
# 2017년.5     6177.0
# 2018년.5     6484.0
# 2019년.5     7243.0
# 2020년.5     7394.0
# 2021년.5     7332.0
# 2017년.6     4364.0
# 2018년.6     4015.0
# 2019년.6     3721.0
# 2020년.6     3881.0
# 2021년.6     3734.0
# 2017년.7    13536.0
# 2018년.7    10379.0
# 2019년.7    10630.0
# 2020년.7    10644.0
# 2021년.7    10601.0
# Name: 4, dtype: float64
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [128], line 7
#       5 print(seoul_data)
#       6 # 응급의학전문의 수 그래프
# ----> 7 plt.plot(years3, seoul_data[~seoul_data.index.str.contains('.7')], marker='o', label='구급차')
#       9 # # 응급의학전공의 수 그래프
#      10 # plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')
#      11
#      12 # 그래프 제목과 축 레이블 설정
#      13 plt.title(f'{cities[0]} 구급차수')
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/matplotlib/pyplot.py:2769, in plot(scalex, scaley, data, *args, **kwargs)
#    2767 @_copy_docstring_and_deprecators(Axes.plot)
#    2768 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2769     return gca().plot(
#    2770         *args, scalex=scalex, scaley=scaley,
#    2771         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py:1632, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1390 """
#    1391 Plot y versus x as lines and/or markers.
#    1392
#    (...)
#    1629 (``'green'``) or hex strings (``'#008000'``).
#    1630 """
#    1631 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633 for line in lines:
#    1634     self.add_line(line)
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py:312, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     310     this += args[0],
#     311     args = args[1:]
# --> 312 yield from self._plot_args(this, kwargs)
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py:498, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs)
#     495     self.axes.yaxis.update_units(y)
#     497 if x.shape[0] != y.shape[0]:
# --> 498     raise ValueError(f"x and y must have same first dimension, but "
#     499                      f"have shapes {x.shape} and {y.shape}")
#     500 if x.ndim > 2 or y.ndim > 2:
#     501     raise ValueError(f"x and y can be no greater than 2D, but have "
#     502                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (5,) and (12,)

# %%
df_7.head(10)
# Out:
#     2017년   2018년   2019년   2020년   2021년  분류   2017년.5   2018년.5   2019년.5  \
# 0  전체 구급차  전체 구급차  전체 구급차  전체 구급차  전체 구급차  분류      탑승인력      탑승인력      탑승인력
# 1       계       계       계       계       계  분류  1급 응급구조사  1급 응급구조사  1급 응급구조사
# 2       대       대       대       대       대  분류         명         명         명
# 3     원자료     원자료     원자료     원자료     원자료  분류       원자료       원자료       원자료
# 4    7764    7800    7740    7668    7569  전체      6177      6484      7243
# 5     807     830     803     791     813  서울       832       807       803
# 6     401     416     432     432     411  부산       241       216       231
# 7     303     302     309     314     303  대구       215       203       246
# 8     332     331     332     306     301  인천       458       454       517
# 9     235     241     246     261     242  광주       307       317       317
#
#     2020년.5  ...   2017년.6   2018년.6   2019년.6   2020년.6   2021년.6 2017년.7  \
# 0      탑승인력  ...      탑승인력      탑승인력      탑승인력      탑승인력      탑승인력    탑승인력
# 1  1급 응급구조사  ...  2급 응급구조사  2급 응급구조사  2급 응급구조사  2급 응급구조사  2급 응급구조사  의사/간호사
# 2         명  ...         명         명         명         명         명       명
# 3       원자료  ...       원자료       원자료       원자료       원자료       원자료     원자료
# 4      7394  ...      4364      4015      3721      3881      3734   13536
# 5       834  ...       475       535       553       566       594     912
# 6       242  ...       202       257       207       209       204    1217
# 7       258  ...       239       210       165       188       163     742
# 8       520  ...       106        76        96       111       111     548
# 9       324  ...        58        56        43        47        37     611
#
#   2018년.7 2019년.7 2020년.7 2021년.7
# 0    탑승인력    탑승인력    탑승인력    탑승인력
# 1  의사/간호사  의사/간호사  의사/간호사  의사/간호사
# 2       명       명       명       명
# 3     원자료     원자료     원자료     원자료
# 4   10379   10630   10644   10601
# 5     892     840     831     823
# 6    1002     995    1261    1115
# 7     373     593     643     689
# 8     453     496     390     301
# 9     419     377     369     367
#
# [10 rows x 21 columns]

# %%
# 주어진 데이터
seoul_data = df_7.loc[5 + 0]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[years7], marker='o', label='의사/간호사')

# # 응급의학전공의 수 그래프
# plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[0]} 의사/간호사')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
# 주어진 데이터
seoul_data = df_7.loc[5 + 1]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[years7], marker='o', label='의사/간호사')

# # 응급의학전공의 수 그래프
# plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[1]} 의사/간호사')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
# 주어진 데이터
seoul_data = df_7.loc[5 + 2]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[years7], marker='o', label='의사/간호사')

# # 응급의학전공의 수 그래프
# plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[2]} 의사/간호사')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
# 주어진 데이터
seoul_data = df_7.loc[5 + 3]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[years7], marker='o', label='의사/간호사')

# # 응급의학전공의 수 그래프
# plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[4]} 의사/간호사')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
# 주어진 데이터
seoul_data = df_7.loc[5 + 4]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[years7], marker='o', label='의사/간호사')

# # 응급의학전공의 수 그래프
# plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[4]} 의사/간호사')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
# 주어진 데이터
seoul_data = df_7.loc[5 + 5]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[years7], marker='o', label='의사/간호사')

# # 응급의학전공의 수 그래프
# plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[5]} 의사/간호사')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
# 주어진 데이터
seoul_data = df_7.loc[5 + 6]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[years7], marker='o', label='의사/간호사')

# # 응급의학전공의 수 그래프
# plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[6]} 의사/간호사')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
# 주어진 데이터
seoul_data = df_7.loc[5 + 7]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[years7], marker='o', label='의사/간호사')

# # 응급의학전공의 수 그래프
# plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[7]} 의사/간호사')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
# 주어진 데이터
seoul_data = df_7.loc[5 + 8]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[years7], marker='o', label='의사/간호사')

# # 응급의학전공의 수 그래프
# plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[8]} 의사/간호사')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
# 주어진 데이터
seoul_data = df_7.loc[5 + 9]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[years7], marker='o', label='의사/간호사')

# # 응급의학전공의 수 그래프
# plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[9]} 의사/간호사')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
# 주어진 데이터
seoul_data = df_7.loc[5 + 10]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[years7], marker='o', label='의사/간호사')

# # 응급의학전공의 수 그래프
# plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[10]} 의사/간호사')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
# 주어진 데이터
seoul_data = df_7.loc[5 + 11]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[years7], marker='o', label='의사/간호사')

# # 응급의학전공의 수 그래프
# plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[11]} 의사/간호사')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
# 주어진 데이터
seoul_data = df_7.loc[5 + 13]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[years7], marker='o', label='의사/간호사')

# # 응급의학전공의 수 그래프
# plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[13]} 의사/간호사')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
# 주어진 데이터
seoul_data = df_7.loc[5 + 12]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[years7], marker='o', label='의사/간호사')

# # 응급의학전공의 수 그래프
# plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[12]} 의사/간호사')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
# 주어진 데이터
seoul_data = df_7.loc[5 + 13]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[years7], marker='o', label='의사/간호사')

# # 응급의학전공의 수 그래프
# plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[13]} 의사/간호사')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
# 주어진 데이터
seoul_data = df_7.loc[5 + 14]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[years7], marker='o', label='의사/간호사')

# # 응급의학전공의 수 그래프
# plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[14]} 의사/간호사')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
# 주어진 데이터
seoul_data = df_7.loc[5 + 15]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[years7], marker='o', label='의사/간호사')

# # 응급의학전공의 수 그래프
# plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[15]} 의사/간호사')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
# 주어진 데이터
seoul_data = df_7.loc[5 + 16]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[years7], marker='o', label='의사/간호사')

# # 응급의학전공의 수 그래프
# plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[16]} 의사/간호사')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
# 주어진 데이터
seoul_data = df_7.loc[5 + 0]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[years5], marker='o', label='1급 응급 구조사')
plt.plot(years3, seoul_data[years6], marker='o', label='2급 응급 구조사')

# # 응급의학전공의 수 그래프
# plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[0]} 1급 응급 구조사/2급 응급 구조사')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
# 주어진 데이터
seoul_data = df_7.loc[5 + 1]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[years5], marker='o', label='1급 응급 구조사')
plt.plot(years3, seoul_data[years6], marker='o', label='2급 응급 구조사')

# # 응급의학전공의 수 그래프
# plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[1]} 1급 응급 구조사/2급 응급 구조사')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시ㅠ
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
# 주어진 데이터
seoul_data = df_7.loc[5 + 2]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[years5], marker='o', label='1급 응급 구조사')
plt.plot(years3, seoul_data[years6], marker='o', label='2급 응급 구조사')

# # 응급의학전공의 수 그래프
# plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[2]} 1급 응급 구조사/2급 응급 구조사')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시ㅠ
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
# 주어진 데이터
seoul_data = df_7.loc[5 + 3]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[years5], marker='o', label='1급 응급 구조사')
plt.plot(years3, seoul_data[years6], marker='o', label='2급 응급 구조사')

# # 응급의학전공의 수 그래프
# plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[3]} 1급 응급 구조사/2급 응급 구조사')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시ㅠ
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
# 주어진 데이터
seoul_data = df_7.loc[5 + 4]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[years5], marker='o', label='1급 응급 구조사')
plt.plot(years3, seoul_data[years6], marker='o', label='2급 응급 구조사')

# # 응급의학전공의 수 그래프
# plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[4]} 1급 응급 구조사/2급 응급 구조사')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시ㅠ
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
# 주어진 데이터
seoul_data = df_7.loc[5 + 5]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[years5], marker='o', label='1급 응급 구조사')
plt.plot(years3, seoul_data[years6], marker='o', label='2급 응급 구조사')

# # 응급의학전공의 수 그래프
# plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[5]} 1급 응급 구조사/2급 응급 구조사')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시ㅠ
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
# 주어진 데이터
seoul_data = df_7.loc[5 + 6]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[years5], marker='o', label='1급 응급 구조사')
plt.plot(years3, seoul_data[years6], marker='o', label='2급 응급 구조사')

# # 응급의학전공의 수 그래프
# plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[6]} 1급 응급 구조사/2급 응급 구조사')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시ㅠ
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
# 주어진 데이터
seoul_data = df_7.loc[5 + 7]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[years5], marker='o', label='1급 응급 구조사')
plt.plot(years3, seoul_data[years6], marker='o', label='2급 응급 구조사')

# # 응급의학전공의 수 그래프
# plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[7]} 1급 응급 구조사/2급 응급 구조사')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시ㅠ
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
# 주어진 데이터
seoul_data = df_7.loc[5 + 8]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[years5], marker='o', label='1급 응급 구조사')
plt.plot(years3, seoul_data[years6], marker='o', label='2급 응급 구조사')

# # 응급의학전공의 수 그래프
# plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[8]} 1급 응급 구조사/2급 응급 구조사')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시ㅠ
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
# 주어진 데이터
seoul_data = df_7.loc[5 + 9]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[years5], marker='o', label='1급 응급 구조사')
plt.plot(years3, seoul_data[years6], marker='o', label='2급 응급 구조사')

# # 응급의학전공의 수 그래프
# plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[9]} 1급 응급 구조사/2급 응급 구조사')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시ㅠ
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
# 주어진 데이터
seoul_data = df_7.loc[5 + 10]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[years5], marker='o', label='1급 응급 구조사')
plt.plot(years3, seoul_data[years6], marker='o', label='2급 응급 구조사')

# # 응급의학전공의 수 그래프
# plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[10]} 1급 응급 구조사/2급 응급 구조사')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
# 주어진 데이터
seoul_data = df_7.loc[5 + 11]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[years5], marker='o', label='1급 응급 구조사')
plt.plot(years3, seoul_data[years6], marker='o', label='2급 응급 구조사')

# # 응급의학전공의 수 그래프
# plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[11]} 1급 응급 구조사/2급 응급 구조사')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시ㅠ
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
# 주어진 데이터
seoul_data = df_7.loc[5 + 12]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[years5], marker='o', label='1급 응급 구조사')
plt.plot(years3, seoul_data[years6], marker='o', label='2급 응급 구조사')

# # 응급의학전공의 수 그래프
# plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[12]} 1급 응급 구조사/2급 응급 구조사')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시ㅠ
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
# 주어진 데이터
seoul_data = df_7.loc[5 + 13]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[years5], marker='o', label='1급 응급 구조사')
plt.plot(years3, seoul_data[years6], marker='o', label='2급 응급 구조사')

# # 응급의학전공의 수 그래프
# plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[13]} 1급 응급 구조사/2급 응급 구조사')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시ㅠ
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
# 주어진 데이터
seoul_data = df_7.loc[5 + 14]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[years5], marker='o', label='1급 응급 구조사')
plt.plot(years3, seoul_data[years6], marker='o', label='2급 응급 구조사')

# # 응급의학전공의 수 그래프
# plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[14]} 1급 응급 구조사/2급 응급 구조사')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시ㅠ
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
# 주어진 데이터
seoul_data = df_7.loc[5 + 15]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[years5], marker='o', label='1급 응급 구조사')
plt.plot(years3, seoul_data[years6], marker='o', label='2급 응급 구조사')

# # 응급의학전공의 수 그래프
# plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[15]} 1급 응급 구조사/2급 응급 구조사')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시ㅠ
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()

# %%
# 주어진 데이터
seoul_data = df_7.loc[5 + 16]
seoul_data.drop('분류', inplace=True)
seoul_data = seoul_data.astype(float)

# 응급의학전문의 수 그래프
plt.plot(years3, seoul_data[years5], marker='o', label='1급 응급 구조사')
plt.plot(years3, seoul_data[years6], marker='o', label='2급 응급 구조사')

# # 응급의학전공의 수 그래프
# plt.plot(years3, seoul_data[seoul_data.index.str.endswith('.4')], marker='o', label='응급의학전공의 수')

# 그래프 제목과 축 레이블 설정
plt.title(f'{cities[16]} 1급 응급 구조사/2급 응급 구조사')
plt.xlabel('년도')
plt.ylabel('수')

# 범례 표시ㅠ
plt.legend()

# 그리드 표시
plt.grid(True)

# 그래프 표시
plt.show()
