# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
file_path = '/Users/mac/Desktop/빅데이터 프로젝트/시도별 응급실 이용 현황(성별, 연령별).xlsx'
df = pd.read_excel(file_path)
print(df)

#df.plot(kind='hist', subplots=True, layout=(3, 3), sharex=False, sharey=False)
#plt.show()
# Out:
#                                                     No   분류    분류.1   항목   단위  \
# 0                                                    1    계       계   전체    건
# 1                                                    2    계       계   서울    건
# 2                                                    3    계       계   부산    건
# 3                                                    4    계       계   대구    건
# 4                                                    5    계       계   인천    건
# ..                                                 ...  ...     ...  ...  ...
# 387                                                433   여자  80세 이상   전남    건
# 388                                                434   여자  80세 이상   경북    건
# 389                                                435   여자  80세 이상   경남    건
# 390                                                436   여자  80세 이상   제주    건
# 391      [출처] 응급의료 통계연보\n[정의]\n- 의료기관주소지를 기준으로 작성되었...  NaN     NaN  NaN  NaN
#
# ...

# %%
'''0: 전체, 1 : 서울, 2: 부산, 3: 대구, 4: 인천, 5: 광주, 6: 울산, 7: 세종, 8: 경기, 9: 강원, 10: 충북, 11:충남, 12:전북, 13: 전남,
14 : 경북, 15: 경남, 16: 제주'''

total = df.iloc[0:17, -1]
total = total.tolist()

print(total)
# Out:
# [44914623.0, 7639021.0, 2766057.0, 2016224.0, 2234885.0, 1984269.0, 1158053.0, 146432.0, 9715447.0, 1816088.0, 1444398.0, 1830802.0, 1839424.0, 2415404.0, 2381254.0, 3580134.0, 788820.0]

# %%
#남자 1세 미만
m_u_1 = df.iloc[34:51, -1]
m_u_1 = m_u_1.tolist()
#print(m_u_1)

#남자 1-9세
m_u_1t9 = df.iloc[51:68,-1]
m_u_1t9 = m_u_1t9.tolist()
#print(m_u_1t9)

#남자 10-19세
m_u_10t19 = df.iloc[68:85,-1]
m_u_10t19 = m_u_10t19.tolist()
#print(m_u_10t19)

#남자 20-29세
m_u_20t29 = df.iloc[85:102,-1]
m_u_20t29 = m_u_20t29.tolist()
#print(m_u_20t29)

#남자 30-39세
m_u_30t39 = df.iloc[102:119,-1]
m_u_30t39 = m_u_30t39.tolist()
#print(m_u_30t39)

#남자 40-49세
m_u_40t49 = df.iloc[119:136,-1]
m_u_40t49 = m_u_40t49.tolist()
#print(m_u_40t49)

#남자 50-59세
m_u_50t59 = df.iloc[136:153,-1]
m_u_50t59 = m_u_50t59.tolist()
#print(m_u_50t59)

#남자 60-69세
m_u_60t69 = df.iloc[153:170,-1]
m_u_60t69 = m_u_60t69.tolist()
#print(m_u_60t69)

#남자 70-79세
m_u_70t79 = df.iloc[170:187,-1]
m_u_70t79 = m_u_70t79.tolist()
#print(m_u_70t79)

#남자 80
m_u_80 = df.iloc[187:204,-1]
m_u_80 = m_u_80.tolist()
#print(m_u_80)

# %%
#0 : 1, 1: 1-9, 2: 10-19, 3: 20-29, 4: 30-39, 5: 40-49, 6: 50-59, 7: 60-69, 8: 70-79, 9: 80
'''0: 전체, 1 : 서울, 2: 부산, 3: 대구, 4: 인천, 5: 광주, 6: 울산, 7: 세종, 8: 경기, 9: 강원, 10: 충북, 11:충남, 12:전북, 13: 전남,
14 : 경북, 15: 경남, 16: 제주'''
m_data = [m_u_1,m_u_1t9,m_u_10t19,m_u_20t29,m_u_30t39,m_u_40t49,m_u_50t59,m_u_60t69,m_u_70t79,m_u_80]
}

df = pd.DataFrame(data)

# 나이 그룹 레이블 설정 및 역순으로 변경
age_labels = ['Under 1', '1-9', '10-19', '20-29', '30-39', '40-49', '50-59', '60-69', '70-79', '80 and above'][::-1]
df.index = age_labels

# 색상 맵 및 정규화
cmap = plt.get_cmap('viridis')
normalize = plt.Normalize(vmin=df.values.min(), vmax=df.values.max())
colors = [cmap(normalize(value)) for value in df.values.flatten()]

# 플롯 설정
fig, ax = plt.subplots(figsize=(18, 8))

# seaborn의 heatmap 사용
heatmap = sns.heatmap(df, annot=True, fmt=".2%", cmap=cmap, cbar=False, linewidths=.5, ax=ax)

# x축 레이블 설정
ax.set_xlabel('Age Group')
# y축 레이블 설정 (비율은 이미 플롯 안에 표시되므로 생략)
ax.set_ylabel('Age Group')
ax.set_yticklabels(df.index, rotation=0)  # y축 레이블에 나이 그룹 표시

# 색상 바 추가
cbar = heatmap.figure.colorbar(plt.cm.ScalarMappable(cmap=cmap, norm=normalize), ax=heatmap, aspect=10)
cbar.set_label('Color Range')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 각 지역 비율을 데이터프레임으로 변환
data = {
    'Gyeonggi': m_gyeonggi,
    'Gangwon': m_gangwon,
    'Chungbuk': m_chungbuk,
    'Chungnam': m_chungnam,
    'Jeonbuk': m_jeonbuk,
    'Jeonnam': m_jeonnam,
    'Gyeongbuk': m_gyeongbuk,
    'Gyeongnam': m_gyeongnam,
    'Jeju': m_jeju
}

df = pd.DataFrame(data)

# 나이 그룹 레이블 설정 및 역순으로 변경
age_labels = ['Under 1', '1-9', '10-19', '20-29', '30-39', '40-49', '50-59', '60-69', '70-79', '80 and above'][::-1]
df.index = age_labels

# 색상 맵 및 정규화
cmap = plt.get_cmap('viridis')
normalize = plt.Normalize(vmin=df.values.min(), vmax=df.values.max())
colors = [cmap(normalize(value)) for value in df.values.flatten()]

# 플롯 설정
fig, ax = plt.subplots(figsize=(18, 8))

# seaborn의 heatmap 사용
heatmap = sns.heatmap(df, annot=True, fmt=".2%", cmap=cmap, cbar=False, linewidths=.5, ax=ax)

# x축 레이블 설정
ax.set_xlabel('Age Group')
# y축 레이블 설정 (비율은 이미 플롯 안에 표시되므로 생략)
ax.set_ylabel('Age Group')
ax.set_yticklabels(df.index, rotation=0)  # y축 레이블에 나이 그룹 표시

# 색상 바 추가
cbar = heatmap.figure.colorbar(plt.cm.ScalarMappable(cmap=cmap, norm=normalize), ax=heatmap, aspect=10)
cbar.set_label('Color Range')

plt.show()

# %%
##women data

file_path = '/Users/mac/Desktop/빅데이터 프로젝트/시도별 응급실 이용 현황(성별, 연령별).xlsx'
df = pd.read_excel(file_path)
print(df)

#df.plot(kind='hist', subplots=True, layout=(3, 3), sharex=False, sharey=False)
#plt.show()
# Out:
#                                                     No   분류    분류.1   항목   단위  \
# 0                                                    1    계       계   전체    건
# 1                                                    2    계       계   서울    건
# 2                                                    3    계       계   부산    건
# 3                                                    4    계       계   대구    건
# 4                                                    5    계       계   인천    건
# ..                                                 ...  ...     ...  ...  ...
# 387                                                433   여자  80세 이상   전남    건
# 388                                                434   여자  80세 이상   경북    건
# 389                                                435   여자  80세 이상   경남    건
# 390                                                436   여자  80세 이상   제주    건
# 391      [출처] 응급의료 통계연보\n[정의]\n- 의료기관주소지를 기준으로 작성되었...  NaN     NaN  NaN  NaN
#
# ...

# %%
#여자 1세 미만
w_u_1 = df.iloc[221:238, -1]
w_u_1 = w_u_1.tolist()
#print(w_u_1)

#여자 1-9세
w_u_1t9 = df.iloc[238:255,-1]
w_u_1t9 = w_u_1t9.tolist()
#print(w_u_1t9)

#여자 10-19세
w_u_10t19 = df.iloc[255:272,-1]
w_u_10t19 = w_u_10t19.tolist()
#print(w_u_10t19)

#여자 20-29세
w_u_20t29 = df.iloc[272:289,-1]
w_u_20t29 = w_u_20t29.tolist()
#print(w_u_20t29)

#여자 30-39세
w_u_30t39 = df.iloc[289:306,-1]
w_u_30t39 = w_u_30t39.tolist()
#print(w_u_30t39)

#여자 40-49세
w_u_40t49 = df.iloc[306:323,-1]
w_u_40t49 = w_u_40t49.tolist()
#print(w_u_40t49)

#여자 50-59세
w_u_50t59 = df.iloc[323:340,-1]
w_u_50t59 = w_u_50t59.tolist()
#print(w_u_50t59)

#여자 60-69세
w_u_60t69 = df.iloc[340:357,-1]
w_u_60t69 = w_u_60t69.tolist()
#print(m_u_60t69)

#여자 70-79세
w_u_70t79 = df.iloc[357:374,-1]
w_u_70t79 = w_u_70t79.tolist()
#print(w_u_70t79)

#여자 80
w_u_80 = df.iloc[374:391,-1]
w_u_80 = w_u_80.tolist()
print(w_u_80)
# Out:
# [2247671.0, 358150.0, 124236.0, 113225.0, 108886.0, 86200.0, 38034.0, 3525.0, 455793.0, 114362.0, 84622.0, 102365.0, 126431.0, 133864.0, 137451.0, 146771.0, 45300.0]

# %%
#0 : 1, 1: 1-9, 2: 10-19, 3: 20-29, 4: 30-39, 5: 40-49, 6: 50-59, 7: 60-69, 8: 70-79, 9: 80
'''0: 전체, 1 : 서울, 2: 부산, 3: 대구, 4: 인천, 5: 광주, 6: 울산, 7: 세종, 8: 경기, 9: 강원, 10: 충북, 11:충남, 12:전북, 13: 전남,
14 : 경북, 15: 경남, 16: 제주'''
w_data = [w_u_1,w_u_1t9,w_u_10t19,w_u_20t29,w_u_30t39,w_u_40t49,w_u_50t59,w_u_60t69,w_u_70t79,w_u_80]
#print(w_data)
print(w_data[9][1])
# Out:
# 358150.0

# %%
w_seoul = [w_data[0][1]/total[1], w_data[1][1]/total[1], w_data[2][1]/total[1], w_data[3][1]/total[1], w_data[4][1]/total[1], w_data[5][1]/total[1], w_data[6][1]/total[1], w_data[7][1]/total[1], w_data[8][1]/total[1], w_data[9][1]/total[1]]
#print(len(m_seoul))

w_busan = [w_data[0][2]/total[2], w_data[1][2]/total[2], w_data[2][2]/total[2], w_data[3][2]/total[2], w_data[4][2]/total[1], w_data[5][2]/total[2], w_data[6][2]/total[2], w_data[7][2]/total[2], w_data[8][2]/total[2], w_data[9][2]/total[2]]
#print(m_busan)

w_degu = [w_data[0][3]/total[3], w_data[1][3]/total[3], w_data[2][3]/total[3], w_data[3][3]/total[3], w_data[4][3]/total[3], w_data[5][3]/total[3], w_data[6][3]/total[3], w_data[7][3]/total[3], w_data[8][3]/total[3], w_data[9][3]/total[3]]
#print(m_degu)

w_incheon = [w_data[0][4]/total[4], w_data[1][4]/total[4], w_data[2][4]/total[4], w_data[3][4]/total[4], w_data[4][4]/total[4], w_data[5][4]/total[4], w_data[6][4]/total[4], w_data[7][4]/total[4], w_data[8][4]/total[4], w_data[9][4]/total[4]]
#print(m_incheon)

w_gwangju = [w_data[0][5]/total[5], w_data[1][5]/total[5], w_data[2][5]/total[4], w_data[3][5]/total[5], w_data[4][5]/total[5], w_data[5][5]/total[5], w_data[6][5]/total[5], w_data[7][5]/total[5], w_data[8][5]/total[5], w_data[9][5]/total[5]]
#print(m_gwangju)

w_ulsan = [w_data[0][6]/total[6], w_data[1][6]/total[6], w_data[2][6]/total[6], w_data[3][6]/total[6], w_data[4][6]/total[6], w_data[5][6]/total[6], w_data[6][6]/total[6], w_data[7][6]/total[6], w_data[8][6]/total[6], w_data[9][6]/total[6]]
#print(m_ulsan)

w_sejong = [w_data[0][7]/total[7], w_data[1][7]/total[7], w_data[2][7]/total[7], w_data[3][7]/total[7], w_data[4][7]/total[7], w_data[5][7]/total[7], w_data[6][7]/total[7], w_data[7][7]/total[7], w_data[8][7]/total[7], w_data[9][7]/total[7]]
#print(m_sejong)

w_gyeonggi = [w_data[0][8]/total[8], w_data[1][8]/total[8], w_data[2][8]/total[8], w_data[3][8]/total[8], w_data[4][8]/total[8], w_data[5][8]/total[8], w_data[6][8]/total[8], w_data[7][8]/total[8], w_data[8][8]/total[8], w_data[9][8]/total[8]]
#print(m_gyeonggi)

w_gangwon = [w_data[0][9]/total[9], w_data[1][9]/total[9], w_data[2][9]/total[9], w_data[3][9]/total[9], w_data[4][9]/total[9], w_data[5][9]/total[9], w_data[6][9]/total[9], w_data[7][9]/total[9], w_data[8][9]/total[9], w_data[9][9]/total[9]]
#print(m_gangwon)

w_chungbuk = [w_data[0][10]/total[10], w_data[1][10]/total[10], w_data[2][10]/total[10], w_data[3][10]/total[10], w_data[4][10]/total[10], w_data[5][10]/total[10], w_data[6][10]/total[10], w_data[7][10]/total[10], w_data[8][10]/total[10], w_data[9][10]/total[10]]


w_chungnam = [w_data[0][11]/total[11], w_data[1][11]/total[11], w_data[2][11]/total[11], w_data[3][11]/total[11], w_data[4][11]/total[11], w_data[5][11]/total[11], w_data[6][11]/total[11], w_data[7][11]/total[11], w_data[8][11]/total[11], w_data[9][11]/total[11]]


w_jeonbuk = [w_data[0][12]/total[12], w_data[1][12]/total[12], w_data[2][12]/total[12], w_data[3][12]/total[12], w_data[4][12]/total[12], w_data[5][12]/total[12], w_data[6][12]/total[12], w_data[7][12]/total[12], w_data[8][12]/total[12], w_data[9][12]/total[12]]

    
w_jeonnam = [w_data[0][13]/total[13], w_data[1][13]/total[13], w_data[2][13]/total[13], w_data[3][13]/total[13], w_data[4][13]/total[13], w_data[5][13]/total[13], w_data[6][13]/total[13], w_data[7][13]/total[13], w_data[8][13]/total[13], w_data[9][13]/total[13]]

    
w_gyeongbuk = [w_data[0][14]/total[14], w_data[1][14]/total[14], w_data[2][14]/total[14], w_data[3][14]/total[14], w_data[4][14]/total[14], w_data[5][14]/total[14], w_data[6][14]/total[14], w_data[7][14]/total[14], w_data[8][14]/total[14], w_data[9][14]/total[14]]

    
w_gyeongnam = [w_data[0][15]/total[15], w_data[1][15]/total[15], w_data[2][15]/total[15], w_data[3][15]/total[15], w_data[4][15]/total[15], w_data[5][15]/total[15], w_data[6][15]/total[15], w_data[7][15]/total[15], w_data[8][15]/total[15], w_data[9][15]/total[15]]

    
w_jeju = [w_data[0][16]/total[16], w_data[1][16]/total[16], w_data[2][16]/total[16], w_data[3][16]/total[16], w_data[4][16]/total[16], w_data[5][16]/total[16], w_data[6][16]/total[16], w_data[7][16]/total[16], w_data[8][16]/total[16], w_data[9][16]/total[16]]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 각 지역 비율을 데이터프레임으로 변환
data = {
    'Seoul': w_seoul,
    'Busan': w_busan,
    'Daegu': w_degu,
    'Incheon': w_incheon,
    'Gwangju': w_gwangju,
    'Ulsan': w_ulsan,
    'Sejong': w_sejong
    
}

df = pd.DataFrame(data)

# 나이 그룹 레이블 설정 및 역순으로 변경
age_labels = ['Under 1', '1-9', '10-19', '20-29', '30-39', '40-49', '50-59', '60-69', '70-79', '80 and above'][::-1]
df.index = age_labels

# 색상 맵 및 정규화
cmap = plt.get_cmap('viridis')
normalize = plt.Normalize(vmin=df.values.min(), vmax=df.values.max())
colors = [cmap(normalize(value)) for value in df.values.flatten()]

# 플롯 설정
fig, ax = plt.subplots(figsize=(18, 8))

# seaborn의 heatmap 사용
heatmap = sns.heatmap(df, annot=True, fmt=".2%", cmap=cmap, cbar=False, linewidths=.5, ax=ax)

# x축 레이블 설정
ax.set_xlabel('Age Group')
# y축 레이블 설정 (비율은 이미 플롯 안에 표시되므로 생략)
ax.set_ylabel('Age Group')
ax.set_yticklabels(df.index, rotation=0)  # y축 레이블에 나이 그룹 표시

# 색상 바 추가
cbar = heatmap.figure.colorbar(plt.cm.ScalarMappable(cmap=cmap, norm=normalize), ax=heatmap, aspect=10)
cbar.set_label('Color Range')

plt.show()

# %%
# 각 지역 비율을 데이터프레임으로 변환
data = {
    
    'Gyeonggi': w_gyeonggi,
    'Gangwon': w_gangwon,
    'Chungbuk': w_chungbuk,
    'Chungnam': w_chungnam,
    'Jeonbuk': w_jeonbuk,
    'Jeonnam': w_jeonnam,
    'Gyeongbuk': w_gyeongbuk,
    'Gyeongnam': w_gyeongnam,
    'Jeju': w_jeju     
}

df = pd.DataFrame(data)

# 나이 그룹 레이블 설정 및 역순으로 변경
age_labels = ['Under 1', '1-9', '10-19', '20-29', '30-39', '40-49', '50-59', '60-69', '70-79', '80 and above'][::-1]
df.index = age_labels

# 색상 맵 및 정규화
cmap = plt.get_cmap('viridis')
normalize = plt.Normalize(vmin=df.values.min(), vmax=df.values.max())
colors = [cmap(normalize(value)) for value in df.values.flatten()]

# 플롯 설정
fig, ax = plt.subplots(figsize=(18, 8))

# seaborn의 heatmap 사용
heatmap = sns.heatmap(df, annot=True, fmt=".2%", cmap=cmap, cbar=False, linewidths=.5, ax=ax)

# x축 레이블 설정
ax.set_xlabel('Age Group')
# y축 레이블 설정 (비율은 이미 플롯 안에 표시되므로 생략)
ax.set_ylabel('Age Group')
ax.set_yticklabels(df.index, rotation=0)  # y축 레이블에 나이 그룹 표시

# 색상 바 추가
cbar = heatmap.figure.colorbar(plt.cm.ScalarMappable(cmap=cmap, norm=normalize), ax=heatmap, aspect=10)
cbar.set_label('Color Range')

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import font_manager

# 한글 폰트 경로 지정
font_path = '/Users/mac/Desktop/빅데이터 프로젝트/project data/KBIZ한마음명조 B.otf'
font_prop = font_manager.FontProperties(fname=font_path)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import font_manager

# 한글 폰트 경로 지정
font_path = '/Users/mac/Desktop/빅데이터 프로젝트/project data/KBIZ한마음명조 B.otf'
font_prop = font_manager.FontProperties(fname=font_path)

# 데이터프레임 생성
data = {
    '남성': m_seoul[::-1],  # 남성 데이터를 역순으로
    '여성': w_seoul[::-1],  # 여성 데이터를 역순으로
}

df = pd.DataFrame(data)

# 나이 그룹 레이블 설정 및 역순으로 변경
age_labels = ['80세 이상', '70세-79세', '60세-69세', '50세-59세', '40세-49세', '30세-39세', '20세-29세', '10세-19세', '1세-9세', '1세 미만']
df.index = age_labels

# 색상 맵 및 정규화
cmap = plt.get_cmap('viridis')
normalize = plt.Normalize(vmin=df.values.min(), vmax=df.values.max())
colors = [cmap(normalize(value)) for value in df.values.flatten()]

# 플롯 설정
fig, ax = plt.subplots(figsize=(18, 8))

# seaborn의 heatmap 사용
heatmap = sns.heatmap(df, annot=True, fmt=".2%", cmap=cmap, cbar=True, linewidths=.5, ax=ax)

# x축 레이블 설정
ax.set_title('응급실이용현황(연령,성별)\n- 서울 -\n', fontproperties=font_prop, fontsize=25, fontweight='bold')

# y축 레이블 설정 (비율은 이미 플롯 안에 표시되므로 생략)
ax.set_yticklabels(df.index, rotation=0, fontproperties=font_prop, fontweight='bold', fontsize=13)  # y축 레이블에 나이 그룹 표시

# 컬럼 이름에 한글 폰트 적용
ax.set_xticklabels(ax.get_xticklabels(), fontproperties=font_prop, fontsize=15, fontweight='bold')

plt.show()


print(m_seoul)
print(w_seoul)
# Out:
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 50668 (\N{HANGUL SYLLABLE YEO}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 49464 (\N{HANGUL SYLLABLE SE}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.draw()
# ...

# %%
data = {
    '남성': m_busan[::-1],
    '여성': w_busan[::-1]
}

df = pd.DataFrame(data)

# 나이 그룹 레이블 설정 및 역순으로 변경
age_labels = ['1세 미만', '1세-9세', '10세-19세', '20세-29세', '30세-39세', '40세-49세', '50세-59세', '60세-69세', '70세-79세', '80세 이상'][::-1]
df.index = age_labels

# 색상 맵 및 정규화
cmap = plt.get_cmap('viridis')
normalize = plt.Normalize(vmin=df.values.min(), vmax=df.values.max())
colors = [cmap(normalize(value)) for value in df.values.flatten()]

# 플롯 설정
fig, ax = plt.subplots(figsize=(18, 8))

# seaborn의 heatmap 사용
heatmap = sns.heatmap(df, annot=True, fmt=".2%", cmap=cmap, cbar=True, linewidths=.5, ax=ax)

# x축 레이블 설정
ax.set_title('응급실이용현황(연령,성별)\n- 부산 -\n', fontproperties=font_prop, fontsize=25, fontweight='bold')

# y축 레이블 설정 (비율은 이미 플롯 안에 표시되므로 생략)
ax.set_yticklabels(df.index, rotation=0, fontproperties=font_prop, fontweight='bold', fontsize=13)  # y축 레이블에 나이 그룹 표시

# 컬럼 이름에 한글 폰트 적용
ax.set_xticklabels(ax.get_xticklabels(), fontproperties=font_prop, fontsize=15, fontweight='bold')

plt.show()

print(m_busan)
print(w_busan)
# Out:
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 50668 (\N{HANGUL SYLLABLE YEO}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 49464 (\N{HANGUL SYLLABLE SE}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.draw()
# ...

# %%
data = {
    '남성': m_degu[::-1],
    '여성': w_degu[::-1],
}

df = pd.DataFrame(data)

# 나이 그룹 레이블 설정 및 역순으로 변경
age_labels = ['1세 미만', '1세-9세', '10세-19세', '20세-29세', '30세-39세', '40세-49세', '50세-59세', '60세-69세', '70세-79세', '80세 이상'][::-1]
df.index = age_labels

# 색상 맵 및 정규화
cmap = plt.get_cmap('viridis')
normalize = plt.Normalize(vmin=df.values.min(), vmax=df.values.max())
colors = [cmap(normalize(value)) for value in df.values.flatten()]

# 플롯 설정
fig, ax = plt.subplots(figsize=(18, 8))

# seaborn의 heatmap 사용
heatmap = sns.heatmap(df, annot=True, fmt=".2%", cmap=cmap, cbar=True, linewidths=.5, ax=ax)

# x축 레이블 설정
ax.set_title('응급실이용현황(연령,성별)\n- 대구 -\n', fontproperties=font_prop, fontsize=25, fontweight='bold')

# y축 레이블 설정 (비율은 이미 플롯 안에 표시되므로 생략)
ax.set_yticklabels(df.index, rotation=0, fontproperties=font_prop, fontweight='bold', fontsize=13)  # y축 레이블에 나이 그룹 표시

# 컬럼 이름에 한글 폰트 적용
ax.set_xticklabels(ax.get_xticklabels(), fontproperties=font_prop, fontsize=15, fontweight='bold')

plt.show()
# Out:
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 50668 (\N{HANGUL SYLLABLE YEO}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 49464 (\N{HANGUL SYLLABLE SE}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.draw()
# ...

# %%
data = {
    '남성': m_incheon[::-1],
    '여성': w_incheon[::-1]
}

df = pd.DataFrame(data)

# 나이 그룹 레이블 설정 및 역순으로 변경
age_labels = ['1세 미만', '1세-9세', '10세-19세', '20세-29세', '30세-39세', '40세-49세', '50세-59세', '60세-69세', '70세-79세', '80세 이상'][::-1]
df.index = age_labels

# 색상 맵 및 정규화
cmap = plt.get_cmap('viridis')
normalize = plt.Normalize(vmin=df.values.min(), vmax=df.values.max())
colors = [cmap(normalize(value)) for value in df.values.flatten()]

# 플롯 설정
fig, ax = plt.subplots(figsize=(18, 8))

# seaborn의 heatmap 사용
heatmap = sns.heatmap(df, annot=True, fmt=".2%", cmap=cmap, cbar=True, linewidths=.5, ax=ax)

# x축 레이블 설정
ax.set_title('응급실이용현황(연령,성별)\n- 인천 -\n', fontproperties=font_prop, fontsize=25, fontweight='bold')

# y축 레이블 설정 (비율은 이미 플롯 안에 표시되므로 생략)
ax.set_yticklabels(df.index, rotation=0, fontproperties=font_prop, fontweight='bold', fontsize=13)  # y축 레이블에 나이 그룹 표시

# 컬럼 이름에 한글 폰트 적용
ax.set_xticklabels(ax.get_xticklabels(), fontproperties=font_prop, fontsize=15, fontweight='bold')

plt.show()
# Out:
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 50668 (\N{HANGUL SYLLABLE YEO}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 49464 (\N{HANGUL SYLLABLE SE}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.draw()
# ...

# %%
data = {
    '남성': m_gwangju[::-1],
    '여성': w_gwangju[::-1],
}

df = pd.DataFrame(data)

# 나이 그룹 레이블 설정 및 역순으로 변경
age_labels = ['1세 미만', '1세-9세', '10세-19세', '20세-29세', '30세-39세', '40세-49세', '50세-59세', '60세-69세', '70세-79세', '80세 이상'][::-1]
df.index = age_labels

# 색상 맵 및 정규화
cmap = plt.get_cmap('viridis')
normalize = plt.Normalize(vmin=df.values.min(), vmax=df.values.max())
colors = [cmap(normalize(value)) for value in df.values.flatten()]

# 플롯 설정
fig, ax = plt.subplots(figsize=(18, 8))

# seaborn의 heatmap 사용
heatmap = sns.heatmap(df, annot=True, fmt=".2%", cmap=cmap, cbar=True, linewidths=.5, ax=ax)

# x축 레이블 설정
ax.set_title('응급실이용현황(연령,성별)\n- 광주 -\n', fontproperties=font_prop, fontsize=25, fontweight='bold')

# y축 레이블 설정 (비율은 이미 플롯 안에 표시되므로 생략)
ax.set_yticklabels(df.index, rotation=0, fontproperties=font_prop, fontweight='bold', fontsize=13)  # y축 레이블에 나이 그룹 표시

# 컬럼 이름에 한글 폰트 적용
ax.set_xticklabels(ax.get_xticklabels(), fontproperties=font_prop, fontsize=15, fontweight='bold')

plt.show()
# Out:
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 50668 (\N{HANGUL SYLLABLE YEO}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 49464 (\N{HANGUL SYLLABLE SE}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.draw()
# ...

# %%
data = {
    '남성': m_ulsan[::-1],
    '여성': w_ulsan[::-1],
}

df = pd.DataFrame(data)

# 나이 그룹 레이블 설정 및 역순으로 변경
age_labels = ['1세 미만', '1세-9세', '10세-19세', '20세-29세', '30세-39세', '40세-49세', '50세-59세', '60세-69세', '70세-79세', '80세 이상'][::-1]
df.index = age_labels

# 색상 맵 및 정규화
cmap = plt.get_cmap('viridis')
normalize = plt.Normalize(vmin=df.values.min(), vmax=df.values.max())
colors = [cmap(normalize(value)) for value in df.values.flatten()]

# 플롯 설정
fig, ax = plt.subplots(figsize=(18, 8))

# seaborn의 heatmap 사용
heatmap = sns.heatmap(df, annot=True, fmt=".2%", cmap=cmap, cbar=True, linewidths=.5, ax=ax)

# x축 레이블 설정
ax.set_title('응급실이용현황(연령,성별)\n- 울산 -\n', fontproperties=font_prop, fontsize=25, fontweight='bold')

# y축 레이블 설정 (비율은 이미 플롯 안에 표시되므로 생략)
ax.set_yticklabels(df.index, rotation=0, fontproperties=font_prop, fontweight='bold', fontsize=13)  # y축 레이블에 나이 그룹 표시

# 컬럼 이름에 한글 폰트 적용
ax.set_xticklabels(ax.get_xticklabels(), fontproperties=font_prop, fontsize=15, fontweight='bold')

plt.show()
# Out:
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 50668 (\N{HANGUL SYLLABLE YEO}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 49464 (\N{HANGUL SYLLABLE SE}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.draw()
# ...

# %%
data = {
    '남성': m_sejong[::-1],
    '여성': w_sejong[::-1],
}


df = pd.DataFrame(data)

# 나이 그룹 레이블 설정 및 역순으로 변경
age_labels = ['1세 미만', '1세-9세', '10세-19세', '20세-29세', '30세-39세', '40세-49세', '50세-59세', '60세-69세', '70세-79세', '80세 이상'][::-1]
df.index = age_labels

# 색상 맵 및 정규화
cmap = plt.get_cmap('viridis')
normalize = plt.Normalize(vmin=df.values.min(), vmax=df.values.max())
colors = [cmap(normalize(value)) for value in df.values.flatten()]

# 플롯 설정
fig, ax = plt.subplots(figsize=(18, 8))

# seaborn의 heatmap 사용
heatmap = sns.heatmap(df, annot=True, fmt=".2%", cmap=cmap, cbar=True, linewidths=.5, ax=ax)

# x축 레이블 설정
ax.set_title('응급실이용현황(연령,성별)\n- 세종 -\n', fontproperties=font_prop, fontsize=25, fontweight='bold')

# y축 레이블 설정 (비율은 이미 플롯 안에 표시되므로 생략)
ax.set_yticklabels(df.index, rotation=0, fontproperties=font_prop, fontweight='bold', fontsize=13)  # y축 레이블에 나이 그룹 표시

# 컬럼 이름에 한글 폰트 적용
ax.set_xticklabels(ax.get_xticklabels(), fontproperties=font_prop, fontsize=15, fontweight='bold')

plt.show()
# Out:
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 50668 (\N{HANGUL SYLLABLE YEO}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 49464 (\N{HANGUL SYLLABLE SE}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.draw()
# ...

# %%
data = {
    '남성': m_gyeonggi[::-1],
    '여성': w_gyeonggi[::-1],
}


df = pd.DataFrame(data)

# 나이 그룹 레이블 설정 및 역순으로 변경
age_labels = ['1세 미만', '1세-9세', '10세-19세', '20세-29세', '30세-39세', '40세-49세', '50세-59세', '60세-69세', '70세-79세', '80세 이상'][::-1]
df.index = age_labels

# 색상 맵 및 정규화
cmap = plt.get_cmap('viridis')
normalize = plt.Normalize(vmin=df.values.min(), vmax=df.values.max())
colors = [cmap(normalize(value)) for value in df.values.flatten()]

# 플롯 설정
fig, ax = plt.subplots(figsize=(18, 8))

# seaborn의 heatmap 사용
heatmap = sns.heatmap(df, annot=True, fmt=".2%", cmap=cmap, cbar=True, linewidths=.5, ax=ax)

# x축 레이블 설정
ax.set_title('응급실이용현황(연령,성별)\n- 경기 -\n', fontproperties=font_prop, fontsize=25, fontweight='bold')

# y축 레이블 설정 (비율은 이미 플롯 안에 표시되므로 생략)
ax.set_yticklabels(df.index, rotation=0, fontproperties=font_prop, fontweight='bold', fontsize=13)  # y축 레이블에 나이 그룹 표시

# 컬럼 이름에 한글 폰트 적용
ax.set_xticklabels(ax.get_xticklabels(), fontproperties=font_prop, fontsize=15, fontweight='bold')

plt.show()
# Out:
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 50668 (\N{HANGUL SYLLABLE YEO}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 49464 (\N{HANGUL SYLLABLE SE}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.draw()
# ...

# %%
data = {
    '남성': m_gangwon[::-1],
    '여성': w_gangwon[::-1],
}

df = pd.DataFrame(data)

# 나이 그룹 레이블 설정 및 역순으로 변경
age_labels = ['1세 미만', '1세-9세', '10세-19세', '20세-29세', '30세-39세', '40세-49세', '50세-59세', '60세-69세', '70세-79세', '80세 이상'][::-1]
df.index = age_labels

# 색상 맵 및 정규화
cmap = plt.get_cmap('viridis')
normalize = plt.Normalize(vmin=df.values.min(), vmax=df.values.max())
colors = [cmap(normalize(value)) for value in df.values.flatten()]

# 플롯 설정
fig, ax = plt.subplots(figsize=(18, 8))

# seaborn의 heatmap 사용
heatmap = sns.heatmap(df, annot=True, fmt=".2%", cmap=cmap, cbar=True, linewidths=.5, ax=ax)

# x축 레이블 설정
ax.set_title('응급실이용현황(연령,성별)\n- 강원 -\n', fontproperties=font_prop, fontsize=25, fontweight='bold')

# y축 레이블 설정 (비율은 이미 플롯 안에 표시되므로 생략)
ax.set_yticklabels(df.index, rotation=0, fontproperties=font_prop, fontweight='bold', fontsize=13)  # y축 레이블에 나이 그룹 표시

# 컬럼 이름에 한글 폰트 적용
ax.set_xticklabels(ax.get_xticklabels(), fontproperties=font_prop, fontsize=15, fontweight='bold')

plt.show()
# Out:
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 50668 (\N{HANGUL SYLLABLE YEO}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 49464 (\N{HANGUL SYLLABLE SE}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.draw()
# ...

# %%
data = {
    '남성': m_chungbuk[::-1],
    '여성': w_chungbuk[::-1],

}

df = pd.DataFrame(data)

# 나이 그룹 레이블 설정 및 역순으로 변경
age_labels = ['1세 미만', '1세-9세', '10세-19세', '20세-29세', '30세-39세', '40세-49세', '50세-59세', '60세-69세', '70세-79세', '80세 이상'][::-1]
df.index = age_labels

# 색상 맵 및 정규화
cmap = plt.get_cmap('viridis')
normalize = plt.Normalize(vmin=df.values.min(), vmax=df.values.max())
colors = [cmap(normalize(value)) for value in df.values.flatten()]

# 플롯 설정
fig, ax = plt.subplots(figsize=(18, 8))

# seaborn의 heatmap 사용
heatmap = sns.heatmap(df, annot=True, fmt=".2%", cmap=cmap, cbar=True, linewidths=.5, ax=ax)

# x축 레이블 설정
ax.set_title('응급실이용현황(연령,성별)\n- 충북 -\n', fontproperties=font_prop, fontsize=25, fontweight='bold')

# y축 레이블 설정 (비율은 이미 플롯 안에 표시되므로 생략)
ax.set_yticklabels(df.index, rotation=0, fontproperties=font_prop, fontweight='bold', fontsize=13)  # y축 레이블에 나이 그룹 표시

# 컬럼 이름에 한글 폰트 적용
ax.set_xticklabels(ax.get_xticklabels(), fontproperties=font_prop, fontsize=15, fontweight='bold')

plt.show()
# Out:
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 50668 (\N{HANGUL SYLLABLE YEO}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 49464 (\N{HANGUL SYLLABLE SE}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.draw()
# ...

# %%
data = {
    '남성': m_chungnam[::-1],
    '여성': w_chungnam[::-1],

}


df = pd.DataFrame(data)

# 나이 그룹 레이블 설정 및 역순으로 변경
age_labels = ['1세 미만', '1세-9세', '10세-19세', '20세-29세', '30세-39세', '40세-49세', '50세-59세', '60세-69세', '70세-79세', '80세 이상'][::-1]
df.index = age_labels

# 색상 맵 및 정규화
cmap = plt.get_cmap('viridis')
normalize = plt.Normalize(vmin=df.values.min(), vmax=df.values.max())
colors = [cmap(normalize(value)) for value in df.values.flatten()]

# 플롯 설정
fig, ax = plt.subplots(figsize=(18, 8))

# seaborn의 heatmap 사용
heatmap = sns.heatmap(df, annot=True, fmt=".2%", cmap=cmap, cbar=True, linewidths=.5, ax=ax)

# x축 레이블 설정
ax.set_title('응급실이용현황(연령,성별)\n- 충남 -\n', fontproperties=font_prop, fontsize=25, fontweight='bold')

# y축 레이블 설정 (비율은 이미 플롯 안에 표시되므로 생략)
ax.set_yticklabels(df.index, rotation=0, fontproperties=font_prop, fontweight='bold', fontsize=13)  # y축 레이블에 나이 그룹 표시

# 컬럼 이름에 한글 폰트 적용
ax.set_xticklabels(ax.get_xticklabels(), fontproperties=font_prop, fontsize=15, fontweight='bold')

plt.show()
# Out:
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 50668 (\N{HANGUL SYLLABLE YEO}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 49464 (\N{HANGUL SYLLABLE SE}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.draw()
# ...

# %%
data = {
    '남성': m_jeonbuk[::-1],
    '여성': w_jeonbuk[::-1],
}


df = pd.DataFrame(data)

# 나이 그룹 레이블 설정 및 역순으로 변경
age_labels = ['1세 미만', '1세-9세', '10세-19세', '20세-29세', '30세-39세', '40세-49세', '50세-59세', '60세-69세', '70세-79세', '80세 이상'][::-1]
df.index = age_labels

# 색상 맵 및 정규화
cmap = plt.get_cmap('viridis')
normalize = plt.Normalize(vmin=df.values.min(), vmax=df.values.max())
colors = [cmap(normalize(value)) for value in df.values.flatten()]

# 플롯 설정
fig, ax = plt.subplots(figsize=(18, 8))

# seaborn의 heatmap 사용
heatmap = sns.heatmap(df, annot=True, fmt=".2%", cmap=cmap, cbar=True, linewidths=.5, ax=ax)

# x축 레이블 설정
ax.set_title('응급실이용현황(연령,성별)\n- 전북 -\n', fontproperties=font_prop, fontsize=25, fontweight='bold')

# y축 레이블 설정 (비율은 이미 플롯 안에 표시되므로 생략)
ax.set_yticklabels(df.index, rotation=0, fontproperties=font_prop, fontweight='bold', fontsize=13)  # y축 레이블에 나이 그룹 표시

# 컬럼 이름에 한글 폰트 적용
ax.set_xticklabels(ax.get_xticklabels(), fontproperties=font_prop, fontsize=15, fontweight='bold')

plt.show()
# Out:
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 50668 (\N{HANGUL SYLLABLE YEO}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 49464 (\N{HANGUL SYLLABLE SE}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.draw()
# ...

# %%
data = {
    '남성': m_jeonnam[::-1],
    '여성': w_jeonnam[::-1],
}


df = pd.DataFrame(data)

# 나이 그룹 레이블 설정 및 역순으로 변경
age_labels = ['1세 미만', '1세-9세', '10세-19세', '20세-29세', '30세-39세', '40세-49세', '50세-59세', '60세-69세', '70세-79세', '80세 이상'][::-1]
df.index = age_labels

# 색상 맵 및 정규화
cmap = plt.get_cmap('viridis')
normalize = plt.Normalize(vmin=df.values.min(), vmax=df.values.max())
colors = [cmap(normalize(value)) for value in df.values.flatten()]

# 플롯 설정
fig, ax = plt.subplots(figsize=(18, 8))

# seaborn의 heatmap 사용
heatmap = sns.heatmap(df, annot=True, fmt=".2%", cmap=cmap, cbar=True, linewidths=.5, ax=ax)

# x축 레이블 설정
ax.set_title('응급실이용현황(연령,성별)\n- 전남 -\n', fontproperties=font_prop, fontsize=25, fontweight='bold')

# y축 레이블 설정 (비율은 이미 플롯 안에 표시되므로 생략)
ax.set_yticklabels(df.index, rotation=0, fontproperties=font_prop, fontweight='bold', fontsize=13)  # y축 레이블에 나이 그룹 표시

# 컬럼 이름에 한글 폰트 적용
ax.set_xticklabels(ax.get_xticklabels(), fontproperties=font_prop, fontsize=15, fontweight='bold')

plt.show()
# Out:
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 50668 (\N{HANGUL SYLLABLE YEO}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 49464 (\N{HANGUL SYLLABLE SE}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.draw()
# ...

# %%
data = {
    '남성': m_gyeongbuk[::-1],
    '여성': w_gyeongbuk[::-1],
}

df = pd.DataFrame(data)

# 나이 그룹 레이블 설정 및 역순으로 변경
age_labels = ['1세 미만', '1세-9세', '10세-19세', '20세-29세', '30세-39세', '40세-49세', '50세-59세', '60세-69세', '70세-79세', '80세 이상'][::-1]
df.index = age_labels

# 색상 맵 및 정규화
cmap = plt.get_cmap('viridis')
normalize = plt.Normalize(vmin=df.values.min(), vmax=df.values.max())
colors = [cmap(normalize(value)) for value in df.values.flatten()]

# 플롯 설정
fig, ax = plt.subplots(figsize=(18, 8))

# seaborn의 heatmap 사용
heatmap = sns.heatmap(df, annot=True, fmt=".2%", cmap=cmap, cbar=True, linewidths=.5, ax=ax)

# x축 레이블 설정
ax.set_title('응급실이용현황(연령,성별)\n- 경북 -\n', fontproperties=font_prop, fontsize=25, fontweight='bold')

# y축 레이블 설정 (비율은 이미 플롯 안에 표시되므로 생략)
ax.set_yticklabels(df.index, rotation=0, fontproperties=font_prop, fontweight='bold', fontsize=13)  # y축 레이블에 나이 그룹 표시

# 컬럼 이름에 한글 폰트 적용
ax.set_xticklabels(ax.get_xticklabels(), fontproperties=font_prop, fontsize=15, fontweight='bold')

plt.show()
# Out:
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 50668 (\N{HANGUL SYLLABLE YEO}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 49464 (\N{HANGUL SYLLABLE SE}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.draw()
# ...

# %%
data = {
    '남성': m_gyeongnam[::-1],
    '여성': w_gyeongnam[::-1],
}


df = pd.DataFrame(data)

# 나이 그룹 레이블 설정 및 역순으로 변경
age_labels = ['1세 미만', '1세-9세', '10세-19세', '20세-29세', '30세-39세', '40세-49세', '50세-59세', '60세-69세', '70세-79세', '80세 이상'][::-1]
df.index = age_labels

# 색상 맵 및 정규화
cmap = plt.get_cmap('viridis')
normalize = plt.Normalize(vmin=df.values.min(), vmax=df.values.max())
colors = [cmap(normalize(value)) for value in df.values.flatten()]

# 플롯 설정
fig, ax = plt.subplots(figsize=(18, 8))

# seaborn의 heatmap 사용
heatmap = sns.heatmap(df, annot=True, fmt=".2%", cmap=cmap, cbar=True, linewidths=.5, ax=ax)

# x축 레이블 설정
ax.set_title('응급실이용현황(연령,성별)\n- 경남 -\n', fontproperties=font_prop, fontsize=25, fontweight='bold')

# y축 레이블 설정 (비율은 이미 플롯 안에 표시되므로 생략)
ax.set_yticklabels(df.index, rotation=0, fontproperties=font_prop, fontweight='bold', fontsize=13)  # y축 레이블에 나이 그룹 표시

# 컬럼 이름에 한글 폰트 적용
ax.set_xticklabels(ax.get_xticklabels(), fontproperties=font_prop, fontsize=15, fontweight='bold')

plt.show()
# Out:
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 50668 (\N{HANGUL SYLLABLE YEO}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 49464 (\N{HANGUL SYLLABLE SE}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.draw()
# ...

# %%
data = {
    '남성': m_jeju[::-1],
    '여성': w_jeju[::-1]
}


df = pd.DataFrame(data)

# 나이 그룹 레이블 설정 및 역순으로 변경
age_labels = ['1세 미만', '1세-9세', '10세-19세', '20세-29세', '30세-39세', '40세-49세', '50세-59세', '60세-69세', '70세-79세', '80세 이상'][::-1]
df.index = age_labels

# 색상 맵 및 정규화
cmap = plt.get_cmap('viridis')
normalize = plt.Normalize(vmin=df.values.min(), vmax=df.values.max())
colors = [cmap(normalize(value)) for value in df.values.flatten()]

# 플롯 설정
fig, ax = plt.subplots(figsize=(18, 8))

# seaborn의 heatmap 사용
heatmap = sns.heatmap(df, annot=True, fmt=".2%", cmap=cmap, cbar=True, linewidths=.5, ax=ax)

# x축 레이블 설정
ax.set_title('응급실이용현황(연령,성별)\n- 제주 -\n', fontproperties=font_prop, fontsize=25, fontweight='bold')

# y축 레이블 설정 (비율은 이미 플롯 안에 표시되므로 생략)
ax.set_yticklabels(df.index, rotation=0, fontproperties=font_prop, fontweight='bold', fontsize=13)  # y축 레이블에 나이 그룹 표시

# 컬럼 이름에 한글 폰트 적용
ax.set_xticklabels(ax.get_xticklabels(), fontproperties=font_prop, fontsize=15, fontweight='bold')

plt.show()
# Out:
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 50668 (\N{HANGUL SYLLABLE YEO}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 49464 (\N{HANGUL SYLLABLE SE}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.draw()
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import font_manager

# 한글 폰트 경로 지정
font_path = '/Users/mac/Desktop/빅데이터 프로젝트/project data/KBIZ한마음명조 B.otf'
font_prop = font_manager.FontProperties(fname=font_path)


m_dejun = [1248/215796,9233/215796,8062/215796,12808/215796,10067/215796,11555/215796,15132/215796,16729/215796,13245/215796,10161/215796]
w_dejun = [921/215796,6357/215796,6270/215796,15898/215796,10266/215796,11582/215796,13901/215796,15012/215796,12482/215796,14867/215796]
data = {
    
    '남성': m_dejun[::-1],
    '여성': w_dejun[::-1],

}


df = pd.DataFrame(data)

# 나이 그룹 레이블 설정 및 역순으로 변경
age_labels = ['1세 미만', '1세-9세', '10세-19세', '20세-29세', '30세-39세', '40세-49세', '50세-59세', '60세-69세', '70세-79세', '80세 이상'][::-1]
df.index = age_labels

# 색상 맵 및 정규화
cmap = plt.get_cmap('viridis')
normalize = plt.Normalize(vmin=df.values.min(), vmax=df.values.max())
colors = [cmap(normalize(value)) for value in df.values.flatten()]

# 플롯 설정
fig, ax = plt.subplots(figsize=(18, 8))

# seaborn의 heatmap 사용
heatmap = sns.heatmap(df, annot=True, fmt=".2%", cmap=cmap, cbar=True, linewidths=.5, ax=ax)

# x축 레이블 설정
ax.set_title('응급실이용현황(연령,성별)\n- 대전 -\n', fontproperties=font_prop, fontsize=25, fontweight='bold')

# y축 레이블 설정 (비율은 이미 플롯 안에 표시되므로 생략)
ax.set_yticklabels(df.index, rotation=0, fontproperties=font_prop, fontweight='bold', fontsize=13)  # y축 레이블에 나이 그룹 표시

# 컬럼 이름에 한글 폰트 적용
ax.set_xticklabels(ax.get_xticklabels(), fontproperties=font_prop, fontsize=15, fontweight='bold')

plt.show()
# Out:
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 50668 (\N{HANGUL SYLLABLE YEO}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 49464 (\N{HANGUL SYLLABLE SE}) missing from current font.
#   fig.canvas.draw()
# /Users/mac/anaconda3/envs/ksj/lib/python3.10/site-packages/seaborn/utils.py:80: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.draw()
# ...
