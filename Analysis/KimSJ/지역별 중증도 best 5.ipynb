# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
file_path = '/Users/mac/Desktop/빅데이터 프로젝트/시도 및 질환별 중증응급환자 구성.xlsx'
df = pd.read_excel(file_path)
print(df)
# Out:
#                                                     No   분류         항목   단위  \
# 0                                                    1   전체  응급실 내원 환자    건
# 1                                                    2   전체     중증응급환자    건
# 2                                                    3   전체      심근경색증    건
# 3                                                    4   전체     허혈성뇌졸중    건
# 4                                                    5   전체      뇌실질출혈    건
# ..                                                 ...  ...        ...  ...
# 566                                                567   미상      급성신부전    건
# 567                                                568   미상      안과적응급    건
# 568                                                569   미상   소생술 후 상태    건
# 569                                                570   미상     비뇨기과응급    건
# 570      [출처] 중증응급질환 응급실 내원 현황 보고서\n[정의] 전체 내원 건수 및...  NaN        NaN  NaN
#
# ...

# %%
seoul_sev = df.iloc[30:60,-1].values.flatten().tolist()
print(seoul_sev)

busan_sev = df.iloc[60:90,-1].values.flatten().tolist()
#print(busan_sev)

degu_sev = df.iloc[90:120,-1].values.flatten().tolist()
#print(degu_sev)

incheon_sev = df.iloc[120:150,-1].values.flatten().tolist()
#print(incheon_sev)

gwanju_sev = df.iloc[150:180,-1].values.flatten().tolist()
#print(gwanju_sev)

dejun_sev = df.iloc[180:210,-1].values.flatten().tolist()
#print(dejun_sev)

ulsan_sev = df.iloc[210:240,-1].values.flatten().tolist()
#print(ulsan_sev)

sejong_sev = df.iloc[240:270,-1].values.flatten().tolist()
#print(sejong_sev)

gyeonggi_sev = df.iloc[270:300,-1].values.flatten().tolist()
#print(gyeonggi_sev)

gangwon_sev = df.iloc[300:330,-1].values.flatten().tolist()
#print(gangwon_sev)

chungbuk_sev = df.iloc[330:360,-1].values.flatten().tolist()

chungnam_sev = df.iloc[360:390, -1].values.flatten().tolist()

jeonbuk_sev = df.iloc[390:420, -1].values.flatten().tolist()

jeonnam_sev  = df.iloc[420:450, -1].values.flatten().tolist()

gyeongbuk_sev = df.iloc[450:480, -1].values.flatten().tolist()

gyeongnam_sev = df.iloc[480:510, -1].values.flatten().tolist()

jeju_sev  = df.iloc[510:540, -1].values.flatten().tolist()
#print(jeju_sev)
# Out:
# [5322335.0, 686553.0, 30778.0, 77500.0, 22952.0, 8425.0, 168765.0, 3662.0, 42857.0, 36206.0, 68696.0, 11682.0, 33627.0, 10027.0, 3955.0, 226.0, 4758.0, 11883.0, 35763.0, 6398.0, 14008.0, 59781.0, 29592.0, 2065.0, 16220.0, 2152.0, 56474.0, 8122.0, 22730.0, 3459.0]

# %%
sorted_indices = sorted(range(2, len(seoul_sev)), key=lambda i: seoul_sev[i], reverse=True)[:5]
seoul_best5 = [(i, seoul_sev[i]) for i in sorted_indices]

sorted_indices = sorted(range(2, len(busan_sev)), key=lambda i: busan_sev[i], reverse=True)[:5]
busan_best5 = [(i, busan_sev[i]) for i in sorted_indices]

sorted_indices = sorted(range(2, len(degu_sev)), key=lambda i: degu_sev[i], reverse=True)[:5]
degu_best5 = [(i, degu_sev[i]) for i in sorted_indices]

sorted_indices = sorted(range(2, len(incheon_sev)), key=lambda i: incheon_sev[i], reverse=True)[:5]
incheon_best5 = [(i, incheon_sev[i]) for i in sorted_indices]

sorted_indices = sorted(range(2, len(gwanju_sev)), key=lambda i: gwanju_sev[i], reverse=True)[:5]
gwanju_best5 = [(i, gwanju_sev[i]) for i in sorted_indices]

sorted_indices = sorted(range(2, len(dejun_sev)), key=lambda i: dejun_sev[i], reverse=True)[:5]
dejun_best5 = [(i, dejun_sev[i]) for i in sorted_indices]

sorted_indices = sorted(range(2, len(ulsan_sev)), key=lambda i: ulsan_sev[i], reverse=True)[:5]
ulsan_best5 = [(i, ulsan_sev[i]) for i in sorted_indices]

sorted_indices = sorted(range(2, len(sejong_sev)), key=lambda i: sejong_sev[i], reverse=True)[:5]
sejong_best5 = [(i, sejong_sev[i]) for i in sorted_indices]

sorted_indices = sorted(range(2, len(gyeonggi_sev)), key=lambda i: gyeonggi_sev[i], reverse=True)[:5]
gyeonggi_best5 = [(i, gyeonggi_sev[i]) for i in sorted_indices]

sorted_indices = sorted(range(2, len(gangwon_sev)), key=lambda i: gangwon_sev[i], reverse=True)[:5]
gangwon_best5 = [(i, gangwon_sev[i]) for i in sorted_indices]

sorted_indices = sorted(range(2, len(chungbuk_sev)), key=lambda i: chungbuk_sev[i], reverse=True)[:5]
chungbuk_best5 = [(i, chungbuk_sev[i]) for i in sorted_indices]

sorted_indices = sorted(range(2, len(chungnam_sev)), key=lambda i: chungnam_sev[i], reverse=True)[:5]
chungnam_best5 = [(i, chungnam_sev[i]) for i in sorted_indices]

sorted_indices = sorted(range(2, len(jeonbuk_sev)), key=lambda i: jeonbuk_sev[i], reverse=True)[:5]
jeonbuk_best5 = [(i, jeonbuk_sev[i]) for i in sorted_indices]

sorted_indices = sorted(range(2, len(jeonnam_sev)), key=lambda i: jeonnam_sev[i], reverse=True)[:5]
jeonnam_best5 = [(i, jeonnam_sev[i]) for i in sorted_indices]

sorted_indices = sorted(range(2, len(gyeongbuk_sev)), key=lambda i: gyeongbuk_sev[i], reverse=True)[:5]
gyeongbuk_best5 = [(i, gyeongbuk_sev[i]) for i in sorted_indices]

sorted_indices = sorted(range(2, len(gyeongnam_sev)), key=lambda i: gyeongnam_sev[i], reverse=True)[:5]
gyeongnam_best5 = [(i, gyeongnam_sev[i]) for i in sorted_indices]

sorted_indices = sorted(range(2, len(jeju_sev)), key=lambda i: jeju_sev[i], reverse=True)[:5]
jeju_best5 = [(i, jeju_sev[i]) for i in sorted_indices]
print(jeju_best5)
# Out:
# [(6, 29358.0), (3, 6741.0), (10, 6687.0), (12, 6117.0), (21, 4869.0)]

# %%
#2: 심근경색증, 3:허혈성뇌졸중, 4:뇌실질출혈, 5:거미막하출혈, 6:중증외상, 7:대동맥박리, 8: 담낭담관질환, 9: 외과계질환, 10: 위장관출혈/이물질, 11: 기관지출혈/이물질, 12 : 중독(CO포함), 13: 주산기질환, 14 : 조산아/저체중아, 15: 중증화상, 16: 간질지속상태, 17: 뇌수막염, 18: 패혈증, 19: 당뇨성혼수, 20: 폐색전/DVT, 21: 부정맥, 22: ARDS/폐부종, 23: DIC, 24: 장중첩/폐색, 25: 사지절단, 26: 급성신부전, 27: 안과적응급, 28: 소생술 후 상태, 29: 비뇨기과응급

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager

# 한글 폰트 경로 지정
font_path = '/Users/mac/Desktop/빅데이터 프로젝트/project data/KBIZ한마음명조 B.otf'
font_prop = font_manager.FontProperties(fname=font_path)

label_dict = {
    2: "심근경색증", 3: "허혈성뇌졸중", 4: "뇌실질출혈", 5: "거미막하출혈", 6: "중증외상", 7: "대동맥박리",
    8: "담낭담관질환", 9: "외과계질환", 10: "위장관출혈/이물질", 11: "기관지출혈/이물질", 12: "중독(CO포함)",
    13: "주산기질환", 14: "조산아/저체중아", 15: "중증화상", 16: "간질지속상태", 17: "뇌수막염", 18: "패혈증",
    19: "당뇨성혼수", 20: "폐색전/DVT", 21: "부정맥", 22: "ARDS/폐부종", 23: "DIC", 24: "장중첩/폐색",
    25: "사지절단", 26: "급성신부전", 27: "안과적응급", 28: "소생술 후 상태", 29: "비뇨기과응급"
}

# 서울 중증 환자 수 총합 (total 정보는 seoul_sev의 0번째 인덱스에 있음)
total_seoul_sev = seoul_sev[0]

# 각 항목의 수치를 비율로 변환
best5_values = [value / total_seoul_sev * 100 for _, value in seoul_best5]

# 폰트 설정
plt.rcParams['font.family'] = font_prop.get_name()

# 시각화
plt.figure(figsize=(10, 6))
bars = plt.bar([label_dict[index] for index, _ in seoul_best5], best5_values, color='#4CAF50')  # 바 색상을 연두색으로 변경
plt.title('중증 환자 수 Best 5 항목\n- 서울 - ', fontproperties=font_prop, fontsize=16)
plt.xlabel('질병 항목', fontproperties=font_prop, fontsize=14)
plt.ylabel('비율 (%)', fontproperties=font_prop, fontsize=14)

# 퍼센테이지 표시 (전체적인 그래프에는 표시하지 않도록 수정)
for bar, value in zip(bars, best5_values):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), f'{value:.2f}%', ha='center', va='bottom', color='black', fontproperties=font_prop, fontsize=12)

plt.show()

# %%
total_busan_sev = busan_sev[0]

# 각 항목의 수치를 비율로 변환
busan_best5_values = [value / total_busan_sev * 100 for _, value in busan_best5]

# 폰트 설정
plt.rcParams['font.family'] = font_prop.get_name()

# 시각화
plt.figure(figsize=(10, 6))
bars = plt.bar([label_dict[index] for index, _ in busan_best5], busan_best5_values, color='#4CAF50')  # 바 색상을 연두색으로 변경
plt.title('중증 환자 수 Best 5 항목\n- 부산 - ', fontproperties=font_prop, fontsize=16)
plt.xlabel('질병 항목', fontproperties=font_prop, fontsize=14)
plt.ylabel('비율 (%)', fontproperties=font_prop, fontsize=14)

# 퍼센테이지 표시 (전체적인 그래프에는 표시하지 않도록 수정)
for bar, value in zip(bars, busan_best5_values):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), f'{value:.2f}%', ha='center', va='bottom', color='black', fontproperties=font_prop, fontsize=12)

plt.show()

# %%
total_degu_sev = degu_sev[0]

# 각 항목의 수치를 비율로 변환
degu_best5_values = [value / total_degu_sev * 100 for _, value in degu_best5]

# 시각화
plt.figure(figsize=(10, 6))
bars = plt.bar([label_dict[index] for index, _ in degu_best5], degu_best5_values, color='#4CAF50')  # 바 색상을 연두색으로 변경
plt.title('중증 환자 수 Best 5 항목\n- 대구 - ', fontproperties=font_prop, fontsize=16)
plt.xlabel('질병 항목', fontproperties=font_prop, fontsize=14)
plt.ylabel('비율 (%)', fontproperties=font_prop, fontsize=14)

# 퍼센테이지 표시 (전체적인 그래프에는 표시하지 않도록 수정)
for bar, value in zip(bars, degu_best5_values):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), f'{value:.2f}%', ha='center', va='bottom', color='black', fontproperties=font_prop, fontsize=12)

plt.show()

# %%
total_incheon_sev = incheon_sev[0]

# 각 항목의 수치를 비율로 변환
incheon_best5_values = [value / total_incheon_sev * 100 for _, value in incheon_best5]

# 시각화
plt.figure(figsize=(10, 6))
bars = plt.bar([label_dict[index] for index, _ in incheon_best5], incheon_best5_values, color='#4CAF50')  # 바 색상을 연두색으로 변경
plt.title('중증 환자 수 Best 5 항목\n- 인천 - ', fontproperties=font_prop, fontsize=16)
plt.xlabel('질병 항목', fontproperties=font_prop, fontsize=14)
plt.ylabel('비율 (%)', fontproperties=font_prop, fontsize=14)

# 퍼센테이지 표시 (전체적인 그래프에는 표시하지 않도록 수정)
for bar, value in zip(bars, incheon_best5_values):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), f'{value:.2f}%', ha='center', va='bottom', color='black', fontproperties=font_prop, fontsize=12)

plt.show()

# %%
total_gwanju_sev = gwanju_sev[0]

# 각 항목의 수치를 비율로 변환
gwanju_best5_values = [value / total_gwanju_sev * 100 for _, value in gwanju_best5]

# 시각화
plt.figure(figsize=(10, 6))
bars = plt.bar([label_dict[index] for index, _ in gwanju_best5], gwanju_best5_values, color='#4CAF50')  # 바 색상을 연두색으로 변경
plt.title('중증 환자 수 Best 5 항목\n- 광주 - ', fontproperties=font_prop, fontsize=16)
plt.xlabel('질병 항목', fontproperties=font_prop, fontsize=14)
plt.ylabel('비율 (%)', fontproperties=font_prop, fontsize=14)

# 퍼센테이지 표시 (전체적인 그래프에는 표시하지 않도록 수정)
for bar, value in zip(bars, gwanju_best5_values):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), f'{value:.2f}%', ha='center', va='bottom', color='black', fontproperties=font_prop, fontsize=12)

plt.show()

# %%
total_dejun_sev = dejun_sev[0]

# 각 항목의 수치를 비율로 변환
dejun_best5_values = [value / total_dejun_sev * 100 for _, value in dejun_best5]

# 시각화
plt.figure(figsize=(10, 6))
bars = plt.bar([label_dict[index] for index, _ in dejun_best5], dejun_best5_values, color='#4CAF50')  # 바 색상을 연두색으로 변경
plt.title('중증 환자 수 Best 5 항목\n- 대전 - ', fontproperties=font_prop, fontsize=16)
plt.xlabel('질병 항목', fontproperties=font_prop, fontsize=14)
plt.ylabel('비율 (%)', fontproperties=font_prop, fontsize=14)

# 퍼센테이지 표시 (전체적인 그래프에는 표시하지 않도록 수정)
for bar, value in zip(bars, dejun_best5_values):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), f'{value:.2f}%', ha='center', va='bottom', color='black', fontproperties=font_prop, fontsize=12)

plt.show()

# %%
total_ulsan_sev = ulsan_sev[0]

# 각 항목의 수치를 비율로 변환
ulsan_best5_values = [value / total_ulsan_sev * 100 for _, value in ulsan_best5]

# 시각화
plt.figure(figsize=(10, 6))
bars = plt.bar([label_dict[index] for index, _ in ulsan_best5], ulsan_best5_values, color='#4CAF50')  # 바 색상을 연두색으로 변경
plt.title('중증 환자 수 Best 5 항목\n- 울산 - ', fontproperties=font_prop, fontsize=16)
plt.xlabel('질병 항목', fontproperties=font_prop, fontsize=14)
plt.ylabel('비율 (%)', fontproperties=font_prop, fontsize=14)

# 퍼센테이지 표시 (전체적인 그래프에는 표시하지 않도록 수정)
for bar, value in zip(bars, ulsan_best5_values):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), f'{value:.2f}%', ha='center', va='bottom', color='black', fontproperties=font_prop, fontsize=12)

plt.show()

# %%
total_sejong_sev = sejong_sev[0]

# 각 항목의 수치를 비율로 변환
sejong_best5_values = [value / total_sejong_sev * 100 for _, value in sejong_best5]

# 시각화
plt.figure(figsize=(10, 6))
bars = plt.bar([label_dict[index] for index, _ in sejong_best5], sejong_best5_values, color='#4CAF50')  # 바 색상을 연두색으로 변경
plt.title('중증 환자 수 Best 5 항목\n- 세종 - ', fontproperties=font_prop, fontsize=16)
plt.xlabel('질병 항목', fontproperties=font_prop, fontsize=14)
plt.ylabel('비율 (%)', fontproperties=font_prop, fontsize=14)

# 퍼센테이지 표시 (전체적인 그래프에는 표시하지 않도록 수정)
for bar, value in zip(bars, sejong_best5_values):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), f'{value:.2f}%', ha='center', va='bottom', color='black', fontproperties=font_prop, fontsize=12)

plt.show()

# %%
total_gyeonggi_sev = gyeonggi_sev[0]

# 각 항목의 수치를 비율로 변환
gyeonggi_best5_values = [value / total_gyeonggi_sev * 100 for _, value in gyeonggi_best5]

# 시각화
plt.figure(figsize=(10, 6))
bars = plt.bar([label_dict[index] for index, _ in gyeonggi_best5], gyeonggi_best5_values, color='#4CAF50')  # 바 색상을 연두색으로 변경
plt.title('중증 환자 수 Best 5 항목\n- 경기 - ', fontproperties=font_prop, fontsize=16)
plt.xlabel('질병 항목', fontproperties=font_prop, fontsize=14)
plt.ylabel('비율 (%)', fontproperties=font_prop, fontsize=14)

# 퍼센테이지 표시 (전체적인 그래프에는 표시하지 않도록 수정)
for bar, value in zip(bars, gyeonggi_best5_values):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), f'{value:.2f}%', ha='center', va='bottom', color='black', fontproperties=font_prop, fontsize=12)

plt.show()

# %%
total_chungnam_sev = chungnam_sev[0]

# 각 항목의 수치를 비율로 변환
chungnam_best5_values = [value / total_chungnam_sev * 100 for _, value in chungnam_best5]

# 시각화
plt.figure(figsize=(10, 6))
bars = plt.bar([label_dict[index] for index, _ in chungnam_best5], chungnam_best5_values, color='#4CAF50')  # 바 색상을 연두색으로 변경
plt.title('중증 환자 수 Best 5 항목\n- 충남 - ', fontproperties=font_prop, fontsize=16)
plt.xlabel('질병 항목', fontproperties=font_prop, fontsize=14)
plt.ylabel('비율 (%)', fontproperties=font_prop, fontsize=14)

# 퍼센테이지 표시 (전체적인 그래프에는 표시하지 않도록 수정)
for bar, value in zip(bars, chungnam_best5_values):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), f'{value:.2f}%', ha='center', va='bottom', color='black', fontproperties=font_prop, fontsize=12)

plt.show()

# %%
total_chungbuk_sev = chungbuk_sev[0]

# 각 항목의 수치를 비율로 변환
chungbuk_best5_values = [value / total_chungbuk_sev * 100 for _, value in chungbuk_best5]

# 시각화
plt.figure(figsize=(10, 6))
bars = plt.bar([label_dict[index] for index, _ in chungbuk_best5], chungbuk_best5_values, color='#4CAF50')  # 바 색상을 연두색으로 변경
plt.title('중증 환자 수 Best 5 항목\n- 충북 - ', fontproperties=font_prop, fontsize=16)
plt.xlabel('질병 항목', fontproperties=font_prop, fontsize=14)
plt.ylabel('비율 (%)', fontproperties=font_prop, fontsize=14)

# 퍼센테이지 표시 (전체적인 그래프에는 표시하지 않도록 수정)
for bar, value in zip(bars, chungbuk_best5_values):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), f'{value:.2f}%', ha='center', va='bottom', color='black', fontproperties=font_prop, fontsize=12)

plt.show()

# %%
total_chungnam_sev = chungnam_sev[0]

# 각 항목의 수치를 비율로 변환
chungnam_best5_values = [value / total_chungnam_sev * 100 for _, value in chungnam_best5]

# 시각화
plt.figure(figsize=(10, 6))
bars = plt.bar([label_dict[index] for index, _ in chungnam_best5], chungnam_best5_values, color='#4CAF50')  # 바 색상을 연두색으로 변경
plt.title('중증 환자 수 Best 5 항목\n- 충남 - ', fontproperties=font_prop, fontsize=16)
plt.xlabel('질병 항목', fontproperties=font_prop, fontsize=14)
plt.ylabel('비율 (%)', fontproperties=font_prop, fontsize=14)

# 퍼센테이지 표시 (전체적인 그래프에는 표시하지 않도록 수정)
for bar, value in zip(bars, chungnam_best5_values):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), f'{value:.2f}%', ha='center', va='bottom', color='black', fontproperties=font_prop, fontsize=12)

plt.show()

# %%
total_jeonbuk_sev = jeonbuk_sev[0]

# 각 항목의 수치를 비율로 변환
jeonbuk_best5_values = [value / total_jeonbuk_sev * 100 for _, value in jeonbuk_best5]

# 시각화
plt.figure(figsize=(10, 6))
bars = plt.bar([label_dict[index] for index, _ in jeonbuk_best5], jeonbuk_best5_values, color='#4CAF50')  # 바 색상을 연두색으로 변경
plt.title('중증 환자 수 Best 5 항목\n- 전북 - ', fontproperties=font_prop, fontsize=16)
plt.xlabel('질병 항목', fontproperties=font_prop, fontsize=14)
plt.ylabel('비율 (%)', fontproperties=font_prop, fontsize=14)

# 퍼센테이지 표시 (전체적인 그래프에는 표시하지 않도록 수정)
for bar, value in zip(bars, jeonbuk_best5_values):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), f'{value:.2f}%', ha='center', va='bottom', color='black', fontproperties=font_prop, fontsize=12)

plt.show()

# %%
total_jeonnam_sev = jeonnam_sev[0]

# 각 항목의 수치를 비율로 변환
jeonnam_best5_values = [value / total_jeonnam_sev * 100 for _, value in jeonnam_best5]

# 시각화
plt.figure(figsize=(10, 6))
bars = plt.bar([label_dict[index] for index, _ in jeonnam_best5], jeonnam_best5_values, color='#4CAF50')  # 바 색상을 연두색으로 변경
plt.title('중증 환자 수 Best 5 항목\n- 전남 - ', fontproperties=font_prop, fontsize=16)
plt.xlabel('질병 항목', fontproperties=font_prop, fontsize=14)
plt.ylabel('비율 (%)', fontproperties=font_prop, fontsize=14)

# 퍼센테이지 표시 (전체적인 그래프에는 표시하지 않도록 수정)
for bar, value in zip(bars, jeonnam_best5_values):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), f'{value:.2f}%', ha='center', va='bottom', color='black', fontproperties=font_prop, fontsize=12)

plt.show()

# %%
total_gyeongbuk_sev = gyeongbuk_sev[0]

# 각 항목의 수치를 비율로 변환
gyeongbuk_best5_values = [value / total_gyeongbuk_sev * 100 for _, value in gyeongbuk_best5]

# 시각화
plt.figure(figsize=(10, 6))
bars = plt.bar([label_dict[index] for index, _ in gyeongbuk_best5], gyeongbuk_best5_values, color='#4CAF50')  # 바 색상을 연두색으로 변경
plt.title('중증 환자 수 Best 5 항목\n- 경북 - ', fontproperties=font_prop, fontsize=16)
plt.xlabel('질병 항목', fontproperties=font_prop, fontsize=14)
plt.ylabel('비율 (%)', fontproperties=font_prop, fontsize=14)

# 퍼센테이지 표시 (전체적인 그래프에는 표시하지 않도록 수정)
for bar, value in zip(bars, gyeongbuk_best5_values):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), f'{value:.2f}%', ha='center', va='bottom', color='black', fontproperties=font_prop, fontsize=12)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
total_gyeongnam_sev = gyeongnam_sev[0]

# 각 항목의 수치를 비율로 변환
gyeongnam_best5_values = [value / total_gyeongnam_sev * 100 for _, value in gyeongnam_best5]

# 시각화
plt.figure(figsize=(10, 6))
bars = plt.bar([label_dict[index] for index, _ in gyeongnam_best5], gyeongnam_best5_values, color='#4CAF50')  # 바 색상을 연두색으로 변경
plt.title('중증 환자 수 Best 5 항목\n- 경남 - ', fontproperties=font_prop, fontsize=16)
plt.xlabel('질병 항목', fontproperties=font_prop, fontsize=14)
plt.ylabel('비율 (%)', fontproperties=font_prop, fontsize=14)

# 퍼센테이지 표시 (전체적인 그래프에는 표시하지 않도록 수정)
for bar, value in zip(bars, gyeongnam_best5_values):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), f'{value:.2f}%', ha='center', va='bottom', color='black', fontproperties=font_prop, fontsize=12)

plt.show()

# %%
total_jeju_sev = jeju_sev[0]

# 각 항목의 수치를 비율로 변환
jeju_best5_values = [value / total_jeju_sev * 100 for _, value in jeju_best5]

# 시각화
plt.figure(figsize=(10, 6))
bars = plt.bar([label_dict[index] for index, _ in jeju_best5], jeju_best5_values, color='#4CAF50')  # 바 색상을 연두색으로 변경
plt.title('중증 환자 수 Best 5 항목\n- 제주 - ', fontproperties=font_prop, fontsize=16)
plt.xlabel('질병 항목', fontproperties=font_prop, fontsize=14)
plt.ylabel('비율 (%)', fontproperties=font_prop, fontsize=14)

# 퍼센테이지 표시 (전체적인 그래프에는 표시하지 않도록 수정)
for bar, value in zip(bars, jeju_best5_values):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), f'{value:.2f}%', ha='center', va='bottom', color='black', fontproperties=font_prop, fontsize=12)

plt.show()

# %%
total_gangwon_sev = gangwon_sev[0]

# 각 항목의 수치를 비율로 변환
gangwon_best5_values = [value / total_gangwon_sev * 100 for _, value in gangwon_best5]

# 폰트 설정
plt.rcParams['font.family'] = font_prop.get_name()

# 시각화
plt.figure(figsize=(10, 6))
bars = plt.bar([label_dict[index] for index, _ in gangwon_best5], gangwon_best5_values, color='#4CAF50')  # 바 색상을 연두색으로 변경
plt.title('중증 환자 수 Best 5 항목\n- 강원 - ', fontproperties=font_prop, fontsize=16)
plt.xlabel('질병 항목', fontproperties=font_prop, fontsize=14)
plt.ylabel('비율 (%)', fontproperties=font_prop, fontsize=14)

# 퍼센테이지 표시 (전체적인 그래프에는 표시하지 않도록 수정)
for bar, value in zip(bars, gangwon_best5_values):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), f'{value:.2f}%', ha='center', va='bottom', color='black', fontproperties=font_prop, fontsize=12)

plt.show()
